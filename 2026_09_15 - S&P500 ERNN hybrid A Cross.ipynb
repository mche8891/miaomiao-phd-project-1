# %% [markdown]
# # SPY Hybrid ERNN A Cross-lagged
#
# Original unrestricted model tuning with seven separately estimated nominal levels and the Bitcoin rank-based selection procedure.

# %%
# ============================================================
# SPY MODELLING DATA PREPARATION
# Common setup for all ERNN and QRNN specifications
# ============================================================

from pathlib import Path
import random
import numpy as np
import pandas as pd
import torch


# ------------------------------------------------------------
# 1. Reproducibility and device
# ------------------------------------------------------------

BASE_SEED = 2026

random.seed(BASE_SEED)
np.random.seed(BASE_SEED)
torch.manual_seed(BASE_SEED)

if torch.cuda.is_available():
    torch.cuda.manual_seed_all(BASE_SEED)

device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

print("Device:", device)


# ------------------------------------------------------------
# 2. Load the scaled SPY dataset
# ------------------------------------------------------------

DATA_PATH = Path.home() / "SPY_features_scaled.csv"

df = pd.read_csv(
    DATA_PATH,
    index_col="Date",
    parse_dates=True
)

df = (
    df
    .sort_index()
    .drop_duplicates()
    .dropna()
    .copy()
)


# ------------------------------------------------------------
# 3. Response and predictors
# ------------------------------------------------------------

target_col = "log_return"

feature_cols = [
    "Volatility",
    "RSI_14",
    "ATR_14",
    "QQQ_LogReturns",
    "VIX_LogChange",
    "Volume_LogChange",
]

required_cols = [target_col] + feature_cols

missing_cols = [
    column
    for column in required_cols
    if column not in df.columns
]

if missing_cols:
    raise ValueError(
        "Missing required columns: "
        + ", ".join(missing_cols)
    )


# ------------------------------------------------------------
# 4. Chronological 70%-15%-15% split
# ------------------------------------------------------------

train_size = int(len(df) * 0.70)
val_size = int(len(df) * 0.15)

train_df = df.iloc[:train_size].copy()
val_df = df.iloc[train_size:train_size + val_size].copy()
test_df = df.iloc[train_size + val_size:].copy()


# ------------------------------------------------------------
# 5. Convert samples to tensors
# ------------------------------------------------------------

def dataframe_to_tensors(sample):
    X = torch.tensor(
        sample[feature_cols].to_numpy(),
        dtype=torch.float32,
        device=device
    )
    y = torch.tensor(
        sample[target_col].to_numpy(),
        dtype=torch.float32,
        device=device
    )
    return X, y


X_train, y_train = dataframe_to_tensors(train_df)
X_val, y_val = dataframe_to_tensors(val_df)
X_test, y_test = dataframe_to_tensors(test_df)

# Compatibility aliases used by later QRNN cells.
X_test_q = X_test
y_test_q = y_test

levels = [
    0.025,
    0.050,
    0.250,
    0.500,
    0.750,
    0.950,
    0.975,
]

alpha_levels = levels
tau_levels = levels


# ------------------------------------------------------------
# 6. Checks and split summary
# ------------------------------------------------------------

assert len(X_train) == len(y_train)
assert len(X_val) == len(y_val)
assert len(X_test) == len(y_test)
assert X_train.shape[1] == len(feature_cols)
assert torch.isfinite(X_train).all()
assert torch.isfinite(X_val).all()
assert torch.isfinite(X_test).all()
assert torch.isfinite(y_train).all()
assert torch.isfinite(y_val).all()
assert torch.isfinite(y_test).all()

split_summary = pd.DataFrame({
    "Sample": ["Training", "Validation", "Test"],
    "Observations": [len(train_df), len(val_df), len(test_df)],
    "Start": [
        train_df.index.min().date(),
        val_df.index.min().date(),
        test_df.index.min().date(),
    ],
    "End": [
        train_df.index.max().date(),
        val_df.index.max().date(),
        test_df.index.max().date(),
    ],
})

display(split_summary)

print("Input features:", feature_cols)
print("Number of predictors:", len(feature_cols))
print("X_train shape:", tuple(X_train.shape))
print("X_val shape:  ", tuple(X_val.shape))
print("X_test shape: ", tuple(X_test.shape))
# Out:
# Device: cpu
#        Sample  Observations       Start         End
# 0    Training          2219  2014-01-23  2022-11-11
# 1  Validation           475  2022-11-14  2024-10-04
# 2        Test           476  2024-10-07  2026-08-31
# Input features: ['Volatility', 'RSI_14', 'ATR_14', 'QQQ_LogReturns', 'VIX_LogChange', 'Volume_LogChange']
# Number of predictors: 6
# X_train shape: (2219, 6)
# X_val shape:   (475, 6)
# X_test shape:  (476, 6)

# %% [markdown]
# ## Original tuning
#
# Run this cell after the SPY data-preparation cell.

# %%
# ============================================================
# ORIGINAL TUNING — SPY HYBRID ERNN A CROSS-LAGGED
# Seven separately estimated nominal levels
# 200 Optuna trials per level
# ============================================================

import copy
import json
import time

import optuna
import torch.nn as nn
import torch.nn.functional as F
from optuna.samplers import TPESampler


MODEL_NAME = "spy_ernn_a_cross"
FORM = "A"
LAG_TYPE = "cross"
N_TRIALS = 200
MAX_EPOCHS = 200

TAU_LEVELS = [
    0.025,
    0.050,
    0.250,
    0.500,
    0.750,
    0.950,
    0.975,
]

OUTPUT_DIR = Path("spy_original_tuning_results") / MODEL_NAME
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print("Model:", MODEL_NAME)
print("Output directory:", OUTPUT_DIR.resolve())


# ------------------------------------------------------------
# 1. Reproducibility
# ------------------------------------------------------------

def set_model_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


# ------------------------------------------------------------
# 2. AGD negative log-likelihood
# ------------------------------------------------------------

def hybrid_ernn_loss(y, expectile_forecast, sigma, tau):
    """Mean asymmetric-Gaussian negative log-likelihood."""

    eps = torch.finfo(expectile_forecast.dtype).eps
    sigma = torch.clamp(sigma, min=eps)

    tau_tensor = torch.as_tensor(
        tau,
        dtype=expectile_forecast.dtype,
        device=expectile_forecast.device,
    )

    difference = y - expectile_forecast

    asymmetric_squared_error = (
        torch.abs(
            tau_tensor
            - (difference < 0).to(expectile_forecast.dtype)
        )
        * difference.pow(2)
    )

    pi_tensor = torch.as_tensor(
        torch.pi,
        dtype=expectile_forecast.dtype,
        device=expectile_forecast.device,
    )

    normalising_constant = (
        torch.log(
            torch.sqrt(pi_tensor / tau_tensor)
            + torch.sqrt(pi_tensor / (1.0 - tau_tensor))
        )
        - torch.log(
            torch.as_tensor(
                2.0,
                dtype=expectile_forecast.dtype,
                device=expectile_forecast.device,
            )
        )
    )

    observation_nll = (
        torch.log(sigma)
        + normalising_constant
        + asymmetric_squared_error / sigma.pow(2)
    )

    return observation_nll.mean()


# ------------------------------------------------------------
# 3. CARE-hybrid recursion
# ------------------------------------------------------------

def compute_hybrid_location(
    y,
    X,
    gamma1,
    gamma2,
    gamma3,
    fnn,
    psi,
):
    """A-form cross-lagged CARE-hybrid recursion."""

    fnn_output = fnn(X).squeeze(-1)
    zero_value = y.new_zeros(())

    care_forecasts = [zero_value]
    hybrid_forecasts = [zero_value]

    for time_index in range(1, len(y)):
        previous_return = y[time_index - 1]

        previous_state = hybrid_forecasts[time_index - 1]
        positive_return = torch.clamp(previous_return, min=0)
        negative_return = torch.clamp(-previous_return, min=0)
        care_value = (
            gamma1 * previous_state
            + gamma2 * positive_return
            + gamma3 * negative_return
        )

        hybrid_value = (
            psi * care_value
            + (1.0 - psi) * fnn_output[time_index]
        )

        care_forecasts.append(care_value)
        hybrid_forecasts.append(hybrid_value)

    return (
        torch.stack(hybrid_forecasts),
        torch.stack(care_forecasts),
    )


# ------------------------------------------------------------
# 4. Hybrid ERNN model
# ------------------------------------------------------------

class HybridERNN_A_Cross(nn.Module):
    def __init__(self, input_dim, config):
        super().__init__()

        self.eps = 1e-6

        self.gamma1_raw = nn.Parameter(
            torch.tensor(1.386)
        )

        self.gamma2_raw = nn.Parameter(
            torch.tensor(0.3)
        )

        self.gamma3_raw = nn.Parameter(
            torch.tensor(0.3)
        )
        self.psi_raw = nn.Parameter(
            torch.tensor(0.0)
        )

        self.sigma_raw = nn.Parameter(
            torch.tensor(0.5)
        )

        layers = []
        previous_dimension = input_dim

        for layer_index in range(config["n_hidden_layers"]):
            hidden_dimension = config[f"hidden_dim_{layer_index}"]

            layers.append(
                nn.Linear(previous_dimension, hidden_dimension)
            )

            if config["layernorm"]:
                layers.append(nn.LayerNorm(hidden_dimension))

            layers.append(
                self.get_activation(config["activation"])
            )

            if config["dropout"] > 0:
                layers.append(nn.Dropout(config["dropout"]))

            previous_dimension = hidden_dimension

        layers.append(nn.Linear(previous_dimension, 1))
        self.fnn = nn.Sequential(*layers)

        self.initialise_weights(config["weight_init"])

    @staticmethod
    def get_activation(name):
        return {
            "relu": nn.ReLU(),
            "elu": nn.ELU(),
            "gelu": nn.GELU(),
            "tanh": nn.Tanh(),
        }[name]

    def initialise_weights(self, method):
        for module in self.fnn.modules():
            if not isinstance(module, nn.Linear):
                continue

            if method == "glorot":
                nn.init.xavier_uniform_(module.weight)
            else:
                nn.init.kaiming_uniform_(module.weight)

            if module.bias is not None:
                nn.init.zeros_(module.bias)

    def forward(self, y, X):
        gamma1 = torch.sigmoid(self.gamma1_raw)
        gamma2 = F.softplus(self.gamma2_raw)

        gamma3 = F.softplus(
            self.gamma3_raw
        )
        psi = torch.sigmoid(self.psi_raw)
        sigma = F.softplus(self.sigma_raw) + self.eps

        hybrid_forecast, care_forecast = compute_hybrid_location(
            y=y,
            X=X,
            gamma1=gamma1,
            gamma2=gamma2,
            gamma3=gamma3,
            fnn=self.fnn,
            psi=psi,
        )

        return hybrid_forecast, sigma, care_forecast


# ------------------------------------------------------------
# 5. Original Bitcoin coverage-ratio ranking diagnostic
# ------------------------------------------------------------

def calculate_crp(y, forecast, tau):
    if tau <= 0.5:
        empirical_probability = (
            y <= forecast
        ).float().mean().item()
        target_probability = tau
    else:
        empirical_probability = (
            y > forecast
        ).float().mean().item()
        target_probability = 1.0 - tau

    crp = empirical_probability / target_probability
    crp_penalty = (crp - 1.0) ** 2

    return crp, crp_penalty, empirical_probability


# ------------------------------------------------------------
# 6. Optuna search space
# ------------------------------------------------------------

def suggest_ernn_config(trial):
    config = {
        "n_hidden_layers": trial.suggest_int(
            "n_hidden_layers", 1, 3
        ),
        "activation": trial.suggest_categorical(
            "activation", ["relu", "elu", "gelu", "tanh"]
        ),
        "dropout": trial.suggest_float(
            "dropout", 0.0, 0.5
        ),
        "layernorm": trial.suggest_categorical(
            "layernorm", [True, False]
        ),
        "weight_init": trial.suggest_categorical(
            "weight_init", ["glorot", "he"]
        ),
        "lr": trial.suggest_float(
            "lr", 1e-4, 5e-2, log=True
        ),
        "optimizer": trial.suggest_categorical(
            "optimizer", ["adam", "adamw"]
        ),
        "weight_decay": trial.suggest_float(
            "weight_decay", 0.0, 1e-4
        ),
        "gradient_clip": trial.suggest_categorical(
            "gradient_clip", [0.1, 1.0, 5.0]
        ),
        "patience": trial.suggest_categorical(
            "patience", [10, 20, 30]
        ),
    }

    for layer_index in range(config["n_hidden_layers"]):
        config[f"hidden_dim_{layer_index}"] = trial.suggest_int(
            f"hidden_dim_{layer_index}", 32, 256
        )

    return config


def make_optimizer(model, config):
    arguments = {
        "params": model.parameters(),
        "lr": config["lr"],
        "weight_decay": config["weight_decay"],
    }

    if config["optimizer"] == "adam":
        return torch.optim.Adam(**arguments)

    return torch.optim.AdamW(**arguments)


# ------------------------------------------------------------
# 7. Fit one trial configuration
# ------------------------------------------------------------

def train_ernn_configuration(config, tau, model_seed=BASE_SEED):
    set_model_seed(model_seed)

    model = HybridERNN_A_Cross(
        input_dim=X_train.shape[1],
        config=config,
    ).to(device)

    optimizer = make_optimizer(model, config)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode="min",
        patience=10,
        factor=0.5,
        min_lr=1e-6,
    )

    best_validation_nll = np.inf
    best_model_state = None
    patience_counter = 0
    epochs_completed = 0

    for epoch in range(MAX_EPOCHS):
        epochs_completed = epoch + 1

        model.train()
        optimizer.zero_grad()

        train_forecast, train_sigma, _ = model(y_train, X_train)

        train_loss = hybrid_ernn_loss(
            y=y_train,
            expectile_forecast=train_forecast,
            sigma=train_sigma,
            tau=tau,
        )

        if not torch.isfinite(train_loss):
            return None

        train_loss.backward()

        nn.utils.clip_grad_norm_(
            model.parameters(),
            config["gradient_clip"],
        )

        optimizer.step()

        model.eval()

        with torch.no_grad():
            validation_forecast, validation_sigma, _ = model(
                y_val,
                X_val,
            )

            validation_loss = hybrid_ernn_loss(
                y=y_val,
                expectile_forecast=validation_forecast,
                sigma=validation_sigma,
                tau=tau,
            )

        if not torch.isfinite(validation_loss):
            return None

        scheduler.step(validation_loss)
        current_validation_nll = validation_loss.item()

        if current_validation_nll < best_validation_nll:
            best_validation_nll = current_validation_nll
            best_model_state = copy.deepcopy(model.state_dict())
            patience_counter = 0
        else:
            patience_counter += 1

            if patience_counter >= config["patience"]:
                break

    if best_model_state is None:
        return None

    model.load_state_dict(best_model_state)
    model.eval()

    with torch.no_grad():
        validation_forecast, validation_sigma, _ = model(y_val, X_val)

        validation_nll = hybrid_ernn_loss(
            y=y_val,
            expectile_forecast=validation_forecast,
            sigma=validation_sigma,
            tau=tau,
        ).item()

        (
            validation_crp,
            validation_crp_penalty,
            validation_hit_rate,
        ) = calculate_crp(
            y=y_val,
            forecast=validation_forecast,
            tau=tau,
        )

    parameters = {
        "gamma1": torch.sigmoid(model.gamma1_raw).item(),
        "gamma2": F.softplus(model.gamma2_raw).item(),
        "gamma3": F.softplus(model.gamma3_raw).item(),
        "psi": torch.sigmoid(model.psi_raw).item(),
        "sigma": (F.softplus(model.sigma_raw) + model.eps).item(),
    }

    return {
        "model": model,
        "validation_nll": validation_nll,
        "validation_crp": validation_crp,
        "validation_crp_penalty": validation_crp_penalty,
        "validation_hit_rate": validation_hit_rate,
        "epochs_completed": epochs_completed,
        **parameters,
    }


# ------------------------------------------------------------
# 8. Optuna objective and rank-based selection
# ------------------------------------------------------------

def objective_ernn(trial, tau):
    config = suggest_ernn_config(trial)
    result = train_ernn_configuration(config, tau)

    if result is None:
        raise optuna.TrialPruned(
            "Non-finite loss or no valid checkpoint."
        )

    for name in [
        "validation_nll",
        "validation_crp",
        "validation_crp_penalty",
        "validation_hit_rate",
        "epochs_completed",
        "gamma1",
        "gamma2",
        "gamma3",
        "psi",
        "sigma",
    ]:
        trial.set_user_attr(name, result[name])

    return result["validation_nll"]


def rank_completed_trials(study):
    completed_trials = [
        trial
        for trial in study.trials
        if (
            trial.state == optuna.trial.TrialState.COMPLETE
            and trial.value is not None
            and np.isfinite(trial.value)
            and "validation_crp_penalty" in trial.user_attrs
        )
    ]

    if not completed_trials:
        raise RuntimeError("No valid completed Optuna trials.")

    nll_order = sorted(
        completed_trials,
        key=lambda trial: trial.user_attrs["validation_nll"],
    )

    crp_order = sorted(
        completed_trials,
        key=lambda trial: trial.user_attrs[
            "validation_crp_penalty"
        ],
    )

    nll_ranks = {
        trial.number: rank
        for rank, trial in enumerate(nll_order, start=1)
    }

    crp_ranks = {
        trial.number: rank
        for rank, trial in enumerate(crp_order, start=1)
    }

    ranking_records = []

    for trial in completed_trials:
        rank_nll = nll_ranks[trial.number]
        rank_crp = crp_ranks[trial.number]

        ranking_records.append({
            "trial": trial.number,
            **trial.user_attrs,
            "rank_nll": rank_nll,
            "rank_crp": rank_crp,
            "sum_rank": rank_nll + rank_crp,
            **trial.params,
        })

    ranking_table = pd.DataFrame(ranking_records)

    ranking_table = ranking_table.sort_values(
        [
            "sum_rank",
            "validation_nll",
            "validation_crp_penalty",
            "trial",
        ]
    ).reset_index(drop=True)

    selected_trial_number = int(ranking_table.iloc[0]["trial"])

    selected_trial = next(
        trial
        for trial in completed_trials
        if trial.number == selected_trial_number
    )

    return selected_trial, ranking_table


# ------------------------------------------------------------
# 9. Run 200 trials at each nominal level
# ------------------------------------------------------------

best_configs_spy_ernn_a_cross = {}
best_models_spy_ernn_a_cross = {}
summary_records = []

overall_start_time = time.time()

for level_index, tau in enumerate(TAU_LEVELS):
    level_start_time = time.time()
    sampler_seed = BASE_SEED + level_index

    print("\n" + "=" * 72)
    print(f"Tuning {MODEL_NAME} at tau={tau:.3f}")
    print(f"Trials={N_TRIALS} | sampler seed={sampler_seed}")
    print("=" * 72)

    study = optuna.create_study(
        direction="minimize",
        sampler=TPESampler(seed=sampler_seed),
        study_name=f"{MODEL_NAME}_tau_{tau:.3f}",
    )

    study.optimize(
        lambda trial, current_tau=tau: objective_ernn(
            trial,
            current_tau,
        ),
        n_trials=N_TRIALS,
        show_progress_bar=True,
        gc_after_trial=True,
    )

    selected_trial, ranking_table = rank_completed_trials(study)
    tau_label = f"{tau:.3f}"

    ranking_table.insert(0, "tau", tau)

    ranking_path = OUTPUT_DIR / (
        f"{MODEL_NAME}_ranking_tau_{tau_label}.csv"
    )

    ranking_table.to_csv(ranking_path, index=False)

    selected_config = selected_trial.params.copy()

    selected_result = train_ernn_configuration(
        selected_config,
        tau,
    )

    if selected_result is None:
        raise RuntimeError(
            f"Selected trial could not be reproduced for tau={tau}."
        )

    selected_model = selected_result["model"]

    checkpoint_path = OUTPUT_DIR / (
        f"{MODEL_NAME}_best_tau_{tau_label}.pt"
    )

    torch.save(
        {
            "model_name": MODEL_NAME,
            "asset": "SPY",
            "form": FORM,
            "lag_type": LAG_TYPE,
            "tau": tau,
            "selected_trial": selected_trial.number,
            "config": selected_config,
            "model_state_dict": {
                key: value.detach().cpu()
                for key, value in selected_model.state_dict().items()
            },
            "validation_nll": selected_result["validation_nll"],
            "validation_crp": selected_result["validation_crp"],
            "validation_crp_penalty": selected_result[
                "validation_crp_penalty"
            ],
            "validation_hit_rate": selected_result[
                "validation_hit_rate"
            ],
            "estimated_parameters": {
                name: selected_result[name]
                for name in [
                    "gamma1",
                    "gamma2",
                    "gamma3",
                    "psi",
                    "sigma",
                ]
            },
            "feature_cols": feature_cols,
            "number_of_trials": N_TRIALS,
            "base_seed": BASE_SEED,
            "sampler_seed": sampler_seed,
        },
        checkpoint_path,
    )

    selected_record = {
        **selected_config,
        "selected_trial": selected_trial.number,
        **{
            name: selected_result[name]
            for name in [
                "validation_nll",
                "validation_crp",
                "validation_crp_penalty",
                "validation_hit_rate",
                "gamma1",
                "gamma2",
                "gamma3",
                "psi",
                "sigma",
            ]
        },
    }

    best_configs_spy_ernn_a_cross[tau] = selected_record
    best_models_spy_ernn_a_cross[tau] = selected_model

    runtime_hours = (
        time.time() - level_start_time
    ) / 3600

    summary_records.append({
        "tau": tau,
        "selected_trial": selected_trial.number,
        "validation_nll": selected_result["validation_nll"],
        "validation_crp": selected_result["validation_crp"],
        "validation_crp_penalty": selected_result[
            "validation_crp_penalty"
        ],
        "validation_hit_rate": selected_result[
            "validation_hit_rate"
        ],
        "gamma1": selected_result["gamma1"],
        "gamma2": selected_result["gamma2"],
        "gamma3": selected_result["gamma3"],
        "psi": selected_result["psi"],
        "sigma": selected_result["sigma"],
        "valid_trials": len(ranking_table),
        "runtime_hours": runtime_hours,
    })

    print("\nTop 10 rank-based trials:")
    print(
        ranking_table[[
            "trial",
            "validation_nll",
            "validation_crp",
            "validation_crp_penalty",
            "rank_nll",
            "rank_crp",
            "sum_rank",
        ]].head(10).to_string(index=False)
    )

    print("\nSelected trial:", selected_trial.number)
    print(
        "Validation NLL:",
        f"{selected_result['validation_nll']:.8f}",
    )
    print(
        "Validation CRP:",
        f"{selected_result['validation_crp']:.8f}",
    )
    print("Ranking saved to:", ranking_path)
    print("Checkpoint saved to:", checkpoint_path)


summary_spy_ernn_a_cross = pd.DataFrame(summary_records)

summary_path = OUTPUT_DIR / f"{MODEL_NAME}_tuning_summary.csv"
summary_spy_ernn_a_cross.to_csv(summary_path, index=False)

config_path = OUTPUT_DIR / f"{MODEL_NAME}_selected_configs.json"

with open(config_path, "w") as configuration_file:
    json.dump(
        {
            f"{tau:.3f}": config
            for tau, config in best_configs_spy_ernn_a_cross.items()
        },
        configuration_file,
        indent=2,
    )

print("\n" + "=" * 72)
print("SPY ORIGINAL ERNN TUNING COMPLETED:", MODEL_NAME)
print("=" * 72)
display(summary_spy_ernn_a_cross)

print(
    "Total runtime (hours):",
    f"{(time.time() - overall_start_time) / 3600:.3f}",
)
print("Summary saved to:", summary_path)
print("Selected configurations saved to:", config_path)
# Out:
# [I 2026-09-15 13:35:48,574] A new study created in memory with name: spy_ernn_a_cross_tau_0.025
# Model: spy_ernn_a_cross
# Output directory: /Users/miaomiaochen/Desktop/PhD program/Project 1/spy_original_tuning_results/spy_ernn_a_cross
#
# ========================================================================
# Tuning spy_ernn_a_cross at tau=0.025
# Trials=200 | sampler seed=2026
# ========================================================================
#   0%|          | 0/200 [00:00<?, ?it/s]
# [I 2026-09-15 13:36:08,974] Trial 0 finished with value: 1.7644333839416504 and parameters: {'n_hidden_layers': 1, 'activation': 'elu', 'dropout': 0.49377524711883497, 'layernorm': False, 'weight_init': 'he', 'lr': 0.0006552020421842752, 'optimizer': 'adam', 'weight_decay': 8.940884610144999e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 38}. Best is trial 0 with value: 1.7644333839416504.
# [I 2026-09-15 13:36:32,683] Trial 1 finished with value: 0.7222895622253418 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.07458356653667625, 'layernorm': False, 'weight_init': 'he', 'lr': 0.006969178688110181, 'optimizer': 'adam', 'weight_decay': 2.574006001095316e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 102}. Best is trial 1 with value: 0.7222895622253418.
# [I 2026-09-15 13:36:35,172] Trial 2 finished with value: 1.8489314317703247 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.37112272198735796, 'layernorm': True, 'weight_init': 'he', 'lr': 0.00010150090104324205, 'optimizer': 'adam', 'weight_decay': 6.518207314586205e-05, 'gradient_clip': 0.1, 'patience': 20, 'hidden_dim_0': 164}. Best is trial 1 with value: 0.7222895622253418.
# [I 2026-09-15 13:36:59,746] Trial 3 finished with value: 1.5954506397247314 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.08410371275195383, 'layernorm': False, 'weight_init': 'he', 'lr': 0.0018347830260217095, 'optimizer': 'adamw', 'weight_decay': 1.0709415904194131e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 237}. Best is trial 1 with value: 0.7222895622253418.
# [I 2026-09-15 13:37:23,281] Trial 4 finished with value: 1.228308916091919 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.04674566511461714, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.004179064253320389, 'optimizer': 'adam', 'weight_decay': 6.125656858808738e-05, 'gradient_clip': 5.0, 'patience': 20, 'hidden_dim_0': 104}. Best is trial 1 with value: 0.7222895622253418.
# [I 2026-09-15 13:37:25,910] Trial 5 finished with value: 1.8673940896987915 and parameters: {'n_hidden_layers': 2, 'activation': 'elu', 'dropout': 0.45911076747236795, 'layernorm': True, 'weight_init': 'he', 'lr': 0.0001416875352388753, 'optimizer': 'adam', 'weight_decay': 9.345394674549201e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 223, 'hidden_dim_1': 87}. Best is trial 1 with value: 0.7222895622253418.
# [I 2026-09-15 13:37:51,541] Trial 6 finished with value: 1.7641264200210571 and parameters: {'n_hidden_layers': 2, 'activation': 'elu', 'dropout': 0.38970064512862934, 'layernorm': True, 'weight_init': 'he', 'lr': 0.0006254792571683692, 'optimizer': 'adamw', 'weight_decay': 6.801313798751197e-05, 'gradient_clip': 0.1, 'patience': 10, 'hidden_dim_0': 218, 'hidden_dim_1': 178}. Best is trial 1 with value: 0.7222895622253418.
# [I 2026-09-15 13:37:56,663] Trial 7 finished with value: 1.8477849960327148 and parameters: {'n_hidden_layers': 2, 'activation': 'gelu', 'dropout': 0.36032432475263065, 'layernorm': True, 'weight_init': 'he', 'lr': 0.00020173841324002415, 'optimizer': 'adam', 'weight_decay': 4.1767279869402754e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0': 154, 'hidden_dim_1': 109}. Best is trial 1 with value: 0.7222895622253418.
# [I 2026-09-15 13:37:58,192] Trial 8 finished with value: 1.8464463949203491 and parameters: {'n_hidden_layers': 3, 'activation': 'relu', 'dropout': 0.4362763457742629, 'layernorm': False, 'weight_init': 'he', 'lr': 0.0005717356849949265, 'optimizer': 'adamw', 'weight_decay': 9.916771691263823e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 79, 'hidden_dim_1': 56, 'hidden_dim_2': 37}. Best is trial 1 with value: 0.7222895622253418.
# [I 2026-09-15 13:38:01,191] Trial 9 finished with value: 1.8453916311264038 and parameters: {'n_hidden_layers': 3, 'activation': 'relu', 'dropout': 0.013151451801451775, 'layernorm': False, 'weight_init': 'he', 'lr': 0.00012716878126572782, 'optimizer': 'adam', 'weight_decay': 1.9095096534588543e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 51, 'hidden_dim_1': 132, 'hidden_dim_2': 126}. Best is trial 1 with value: 0.7222895622253418.
# [I 2026-09-15 13:38:24,131] Trial 10 finished with value: -3.647998809814453 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.15097474024909283, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.037908135375982255, 'optimizer': 'adamw', 'weight_decay': 3.1379335590221484e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 119}. Best is trial 10 with value: -3.647998809814453.
# [I 2026-09-15 13:38:47,114] Trial 11 finished with value: -3.728241205215454 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.16366513375091546, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.03402526330326022, 'optimizer': 'adamw', 'weight_decay': 3.117485972962536e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 121}. Best is trial 11 with value: -3.728241205215454.
# [I 2026-09-15 13:39:10,573] Trial 12 finished with value: -3.9620139598846436 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.19279633488923958, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.046620580362009216, 'optimizer': 'adamw', 'weight_decay': 3.4990129609403785e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 128}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:39:36,494] Trial 13 finished with value: -3.3245491981506348 and parameters: {'n_hidden_layers': 2, 'activation': 'tanh', 'dropout': 0.23786332849750252, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.0422935363306104, 'optimizer': 'adamw', 'weight_decay': 4.3617650808427846e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 192, 'hidden_dim_1': 239}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:39:59,107] Trial 14 finished with value: -1.2101757526397705 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.22057191497197615, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.016347204119543955, 'optimizer': 'adamw', 'weight_decay': 7.599168284062825e-07, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 134}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:40:24,790] Trial 15 finished with value: -1.1023714542388916 and parameters: {'n_hidden_layers': 2, 'activation': 'tanh', 'dropout': 0.16517512170768736, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.016298529041495768, 'optimizer': 'adamw', 'weight_decay': 3.5934740730597646e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 176, 'hidden_dim_1': 242}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:40:47,527] Trial 16 finished with value: -1.385839819908142 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.3070978356512841, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.01725021139952443, 'optimizer': 'adamw', 'weight_decay': 4.984887925511083e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 75}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:41:15,072] Trial 17 finished with value: 0.5215547680854797 and parameters: {'n_hidden_layers': 3, 'activation': 'tanh', 'dropout': 0.14427051645389266, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.00800604547474574, 'optimizer': 'adamw', 'weight_decay': 1.3722887436408784e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 134, 'hidden_dim_1': 180, 'hidden_dim_2': 249}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:41:39,402] Trial 18 finished with value: -3.5237069129943848 and parameters: {'n_hidden_layers': 2, 'activation': 'gelu', 'dropout': 0.290549643868981, 'layernorm': True, 'weight_init': 'glorot', 'lr': 0.0464822393550214, 'optimizer': 'adamw', 'weight_decay': 5.638805838779985e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0': 192, 'hidden_dim_1': 36}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:42:02,250] Trial 19 finished with value: 1.5174187421798706 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.1927867379017451, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.002361491930434552, 'optimizer': 'adamw', 'weight_decay': 7.443533388013251e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 74}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:42:27,062] Trial 20 finished with value: -2.359546184539795 and parameters: {'n_hidden_layers': 2, 'activation': 'tanh', 'dropout': 0.283174479536041, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.026692247869913418, 'optimizer': 'adamw', 'weight_decay': 2.370884689919665e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 105, 'hidden_dim_1': 187}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:42:49,763] Trial 21 finished with value: -3.663789749145508 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.13609573479710535, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.03385701823652554, 'optimizer': 'adamw', 'weight_decay': 3.173883413050123e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 124}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:43:13,164] Trial 22 finished with value: -2.384774923324585 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.11623204631238071, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.023522818899157725, 'optimizer': 'adamw', 'weight_decay': 3.3920964264995576e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 136}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:43:36,184] Trial 23 finished with value: 0.17955760657787323 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.1943188123906569, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.009742581043231096, 'optimizer': 'adamw', 'weight_decay': 4.654281796155235e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 120}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:43:58,826] Trial 24 finished with value: -3.356322765350342 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.11164212777066605, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.02933830423825565, 'optimizer': 'adamw', 'weight_decay': 2.8055355272513846e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 90}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:44:22,905] Trial 25 finished with value: -0.3623254895210266 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.18810747358356134, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.012269864220610192, 'optimizer': 'adamw', 'weight_decay': 3.7891125736284943e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 160}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:44:45,714] Trial 26 finished with value: 1.0693655014038086 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.25739745905240263, 'layernorm': True, 'weight_init': 'glorot', 'lr': 0.005064274241809404, 'optimizer': 'adamw', 'weight_decay': 4.752097352174134e-06, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 120}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:45:09,241] Trial 27 finished with value: -2.2712366580963135 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.10350602008938581, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.022158221130610233, 'optimizer': 'adamw', 'weight_decay': 1.8392981812126922e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 150}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:45:35,122] Trial 28 finished with value: -3.494579792022705 and parameters: {'n_hidden_layers': 2, 'activation': 'elu', 'dropout': 0.023101139951232252, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.04441352442614901, 'optimizer': 'adamw', 'weight_decay': 5.5032391529034675e-05, 'gradient_clip': 0.1, 'patience': 20, 'hidden_dim_0': 187, 'hidden_dim_1': 209}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:45:57,171] Trial 29 finished with value: 1.5855703353881836 and parameters: {'n_hidden_layers': 1, 'activation': 'elu', 'dropout': 0.13723438714190364, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.001901987999795964, 'optimizer': 'adamw', 'weight_decay': 8.319235612617149e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 34}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:46:20,303] Trial 30 finished with value: 1.3466262817382812 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.21975103841619453, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.003422140543726533, 'optimizer': 'adamw', 'weight_decay': 4.197504071434979e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 56}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:46:43,782] Trial 31 finished with value: -3.534075975418091 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.1654329737442582, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.03510235078524342, 'optimizer': 'adamw', 'weight_decay': 3.117366669846731e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 123}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:47:06,904] Trial 32 finished with value: -3.9554309844970703 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.05704005046953832, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.04839331166472875, 'optimizer': 'adamw', 'weight_decay': 2.296929846201317e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 95}. Best is trial 12 with value: -3.9620139598846436.
# [I 2026-09-15 13:47:29,634] Trial 33 finished with value: -3.9817466735839844 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.05970103224479256, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.04864793960764515, 'optimizer': 'adamw', 'weight_decay': 2.5526248485383067e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 93}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:47:53,376] Trial 34 finished with value: -0.5516038537025452 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.0549175378416564, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.013269878135947035, 'optimizer': 'adam', 'weight_decay': 2.2934106381157316e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 93}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:48:21,103] Trial 35 finished with value: -3.890080213546753 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.0652617606746656, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.04748050767635476, 'optimizer': 'adamw', 'weight_decay': 1.2210907054616482e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 60}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:48:46,209] Trial 36 finished with value: -3.8756980895996094 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.0737906823780988, 'layernorm': True, 'weight_init': 'glorot', 'lr': 0.04935374374955817, 'optimizer': 'adam', 'weight_decay': 1.004215167758637e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 57}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:49:10,947] Trial 37 finished with value: 1.716034173965454 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.0474916163087786, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.000990708532822946, 'optimizer': 'adamw', 'weight_decay': 1.096790259142492e-05, 'gradient_clip': 0.1, 'patience': 20, 'hidden_dim_0': 93}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:49:34,651] Trial 38 finished with value: -2.3765294551849365 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.00028232619593288044, 'layernorm': True, 'weight_init': 'he', 'lr': 0.022491482424307124, 'optimizer': 'adam', 'weight_decay': 1.687167605463363e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 63}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:50:02,884] Trial 39 finished with value: 0.9195982217788696 and parameters: {'n_hidden_layers': 2, 'activation': 'elu', 'dropout': 0.07548741586384501, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.005906381327399894, 'optimizer': 'adamw', 'weight_decay': 7.091271493499459e-06, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 47, 'hidden_dim_1': 145}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:50:25,317] Trial 40 finished with value: 0.19351434707641602 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.027936648334363774, 'layernorm': False, 'weight_init': 'he', 'lr': 0.009833827886467765, 'optimizer': 'adamw', 'weight_decay': 2.565401044998999e-05, 'gradient_clip': 5.0, 'patience': 20, 'hidden_dim_0': 104}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:50:48,383] Trial 41 finished with value: -3.860288143157959 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.08823590506138178, 'layernorm': True, 'weight_init': 'glorot', 'lr': 0.04958882992660258, 'optimizer': 'adam', 'weight_decay': 1.3767806642523544e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 62}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:51:12,026] Trial 42 finished with value: -2.5507924556732178 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.055408081425158864, 'layernorm': True, 'weight_init': 'glorot', 'lr': 0.025693479678084424, 'optimizer': 'adam', 'weight_decay': 5.960015211200223e-06, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 84}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:51:35,894] Trial 43 finished with value: -3.836350202560425 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.07929692876373742, 'layernorm': True, 'weight_init': 'glorot', 'lr': 0.047964136835444204, 'optimizer': 'adam', 'weight_decay': 1.976387535012818e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 46}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:52:01,103] Trial 44 finished with value: 1.8215093612670898 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.02851895407538065, 'layernorm': True, 'weight_init': 'glorot', 'lr': 0.0003577912230013811, 'optimizer': 'adam', 'weight_decay': 1.4837412756218117e-06, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 109}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:52:26,412] Trial 45 finished with value: -1.6105884313583374 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.09733911387000199, 'layernorm': True, 'weight_init': 'he', 'lr': 0.018392733222078357, 'optimizer': 'adam', 'weight_decay': 1.0355878968806237e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 253}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:52:49,846] Trial 46 finished with value: -3.2045841217041016 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.06545134338944364, 'layernorm': True, 'weight_init': 'glorot', 'lr': 0.033126942491369035, 'optimizer': 'adam', 'weight_decay': 2.2031317935196107e-05, 'gradient_clip': 0.1, 'patience': 10, 'hidden_dim_0': 68}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:53:13,257] Trial 47 finished with value: 1.6994712352752686 and parameters: {'n_hidden_layers': 2, 'activation': 'tanh', 'dropout': 0.11982265554739834, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.0011008179751772773, 'optimizer': 'adam', 'weight_decay': 2.7556238108158385e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 40, 'hidden_dim_1': 85}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:53:37,422] Trial 48 finished with value: -3.442012310028076 and parameters: {'n_hidden_layers': 2, 'activation': 'tanh', 'dropout': 0.4889989264394104, 'layernorm': False, 'weight_init': 'he', 'lr': 0.03918091343728226, 'optimizer': 'adamw', 'weight_decay': 1.042804067669652e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 89, 'hidden_dim_1': 150}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:54:00,563] Trial 49 finished with value: -2.878943681716919 and parameters: {'n_hidden_layers': 1, 'activation': 'elu', 'dropout': 0.32767919990870387, 'layernorm': True, 'weight_init': 'glorot', 'lr': 0.028368219779894364, 'optimizer': 'adamw', 'weight_decay': 1.4086406030473988e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 78}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:54:28,159] Trial 50 finished with value: -1.5368669033050537 and parameters: {'n_hidden_layers': 3, 'activation': 'tanh', 'dropout': 0.039142049630568755, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.019263729269686492, 'optimizer': 'adamw', 'weight_decay': 3.762945947115574e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 68, 'hidden_dim_1': 210, 'hidden_dim_2': 241}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:54:50,451] Trial 51 finished with value: -3.8174588680267334 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.09079151014340306, 'layernorm': True, 'weight_init': 'glorot', 'lr': 0.04896242664060851, 'optimizer': 'adam', 'weight_decay': 1.4050212296520867e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 57}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:55:13,179] Trial 52 finished with value: -3.7984185218811035 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.0723545089926236, 'layernorm': True, 'weight_init': 'glorot', 'lr': 0.04886148390783754, 'optimizer': 'adam', 'weight_decay': 1.7408425413904726e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 60}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:55:35,896] Trial 53 finished with value: -3.515899419784546 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.012590607439419269, 'layernorm': True, 'weight_init': 'glorot', 'lr': 0.03619711812558615, 'optimizer': 'adam', 'weight_decay': 2.138445499346944e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 32}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:55:58,603] Trial 54 finished with value: -0.7204733490943909 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.12632886781319635, 'layernorm': True, 'weight_init': 'glorot', 'lr': 0.014138920587662186, 'optimizer': 'adam', 'weight_decay': 2.686601925189932e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 99}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:56:21,444] Trial 55 finished with value: -2.96811580657959 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.09372123942137715, 'layernorm': True, 'weight_init': 'glorot', 'lr': 0.029444889503658766, 'optimizer': 'adam', 'weight_decay': 7.969081426202577e-06, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 71}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:56:44,261] Trial 56 finished with value: -3.968520164489746 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.03832291387009008, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.03830377256263586, 'optimizer': 'adam', 'weight_decay': 1.5096047604739055e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 112}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:57:07,434] Trial 57 finished with value: -3.976311683654785 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.04368632428799061, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.03745606389676021, 'optimizer': 'adamw', 'weight_decay': 1.6437496510831515e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 110}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:57:30,267] Trial 58 finished with value: -2.4888954162597656 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.0025580656574794164, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.02259218664284283, 'optimizer': 'adamw', 'weight_decay': 3.4701098153423606e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 111}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:57:53,318] Trial 59 finished with value: -3.9564809799194336 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.4221245740112205, 'layernorm': False, 'weight_init': 'he', 'lr': 0.03819881381575113, 'optimizer': 'adamw', 'weight_decay': 3.4943217220970466e-06, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 144}. Best is trial 33 with value: -3.9817466735839844.
# [I 2026-09-15 13:58:17,249] Trial 60 finished with value: -3.9846549034118652 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.3778911337172916, 'layernorm': False, 'weight_init': 'he', 'lr': 0.036513527576603214, 'optimizer': 'adamw', 'weight_decay': 2.5282900038891756e-06, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 130}. Best is trial 60 with value: -3.9846549034118652.
# [I 2026-09-15 13:58:40,484] Trial 61 finished with value: -3.9536097049713135 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.41746850127360097, 'layernorm': False, 'weight_init': 'he', 'lr': 0.03519086375472846, 'optimizer': 'adamw', 'weight_decay': 2.743164212784725e-07, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 137}. Best is trial 60 with value: -3.9846549034118652.
# [I 2026-09-15 13:59:03,817] Trial 62 finished with value: -3.3482792377471924 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.3466549199473105, 'layernorm': False, 'weight_init': 'he', 'lr': 0.027321959757284842, 'optimizer': 'adamw', 'weight_decay': 3.746304520944791e-06, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 143}. Best is trial 60 with value: -3.9846549034118652.
# [I 2026-09-15 13:59:26,617] Trial 63 finished with value: -4.003289699554443 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.3879129867349748, 'layernorm': False, 'weight_init': 'he', 'lr': 0.038874559482536014, 'optimizer': 'adamw', 'weight_decay': 1.6929130165381173e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 128}. Best is trial 63 with value: -4.003289699554443.
# [I 2026-09-15 13:59:49,610] Trial 64 finished with value: -1.9763139486312866 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.3983950197155894, 'layernorm': False, 'weight_init': 'he', 'lr': 0.01989886463462944, 'optimizer': 'adamw', 'weight_decay': 1.6618102715910917e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 171}. Best is trial 63 with value: -4.003289699554443.
# [I 2026-09-15 14:00:12,756] Trial 65 finished with value: -3.9383325576782227 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.44132337024316093, 'layernorm': False, 'weight_init': 'he', 'lr': 0.03823144073548462, 'optimizer': 'adamw', 'weight_decay': 3.528907271289541e-06, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 130}. Best is trial 63 with value: -4.003289699554443.
# [I 2026-09-15 14:00:36,182] Trial 66 finished with value: -0.9615885615348816 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.3600198835957814, 'layernorm': False, 'weight_init': 'he', 'lr': 0.01526594066439913, 'optimizer': 'adamw', 'weight_decay': 7.226763718966794e-06, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 152}. Best is trial 63 with value: -4.003289699554443.
# [I 2026-09-15 14:00:58,887] Trial 67 finished with value: -3.498455762863159 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.47073562906016236, 'layernorm': False, 'weight_init': 'he', 'lr': 0.028589320752641676, 'optimizer': 'adamw', 'weight_decay': 1.6744564805882647e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 115}. Best is trial 63 with value: -4.003289699554443.
# [I 2026-09-15 14:01:23,896] Trial 68 finished with value: -0.012958651408553123 and parameters: {'n_hidden_layers': 3, 'activation': 'gelu', 'dropout': 0.38498183300815836, 'layernorm': False, 'weight_init': 'he', 'lr': 0.010653957360559472, 'optimizer': 'adamw', 'weight_decay': 3.0171799938209385e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 143, 'hidden_dim_1': 67, 'hidden_dim_2': 34}. Best is trial 63 with value: -4.003289699554443.
# [I 2026-09-15 14:01:46,622] Trial 69 finished with value: -3.8674120903015137 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.4247876344185342, 'layernorm': False, 'weight_init': 'he', 'lr': 0.038937580009977456, 'optimizer': 'adamw', 'weight_decay': 4.62163228080127e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 128}. Best is trial 63 with value: -4.003289699554443.
# [I 2026-09-15 14:02:09,724] Trial 70 finished with value: -3.7792937755584717 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.39371804699663293, 'layernorm': False, 'weight_init': 'he', 'lr': 0.03101956494045555, 'optimizer': 'adamw', 'weight_decay': 2.4678146790151083e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 113}. Best is trial 63 with value: -4.003289699554443.
# [I 2026-09-15 14:02:32,972] Trial 71 finished with value: -4.015344142913818 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.40912447989823486, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04052304290324646, 'optimizer': 'adamw', 'weight_decay': 1.907112841075309e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 127}. Best is trial 71 with value: -4.015344142913818.
# [I 2026-09-15 14:02:56,048] Trial 72 finished with value: -2.763491630554199 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.44943479390105234, 'layernorm': False, 'weight_init': 'he', 'lr': 0.02412241375529786, 'optimizer': 'adamw', 'weight_decay': 1.939190422034368e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 164}. Best is trial 71 with value: -4.015344142913818.
# [I 2026-09-15 14:03:19,515] Trial 73 finished with value: -3.905343770980835 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.3330489062557676, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04009148341185459, 'optimizer': 'adamw', 'weight_decay': 8.279246055905417e-06, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 128}. Best is trial 71 with value: -4.015344142913818.
# [I 2026-09-15 14:03:42,585] Trial 74 finished with value: -3.795527935028076 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.41636387262393526, 'layernorm': False, 'weight_init': 'he', 'lr': 0.03203136566724518, 'optimizer': 'adamw', 'weight_decay': 1.4859791283451265e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 157}. Best is trial 71 with value: -4.015344142913818.
# [I 2026-09-15 14:04:06,709] Trial 75 finished with value: -4.001247406005859 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.3820916265463196, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04018330577737309, 'optimizer': 'adamw', 'weight_decay': 2.9470672344071826e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 139}. Best is trial 71 with value: -4.015344142913818.
# [I 2026-09-15 14:04:29,798] Trial 76 finished with value: -2.1460397243499756 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.3817265705476736, 'layernorm': False, 'weight_init': 'he', 'lr': 0.02065283326063064, 'optimizer': 'adamw', 'weight_decay': 2.962155816589193e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 117}. Best is trial 71 with value: -4.015344142913818.
# [I 2026-09-15 14:04:52,525] Trial 77 finished with value: -3.028653860092163 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.2955445074032528, 'layernorm': False, 'weight_init': 'he', 'lr': 0.025156500443078697, 'optimizer': 'adamw', 'weight_decay': 2.082172712293977e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 102}. Best is trial 71 with value: -4.015344142913818.
# [I 2026-09-15 14:05:16,304] Trial 78 finished with value: -1.3739211559295654 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.35815126221309634, 'layernorm': False, 'weight_init': 'he', 'lr': 0.017008120077689492, 'optimizer': 'adamw', 'weight_decay': 3.921539347426648e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 137}. Best is trial 71 with value: -4.015344142913818.
# [I 2026-09-15 14:05:39,599] Trial 79 finished with value: -4.038172245025635 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.2639188528077098, 'layernorm': False, 'weight_init': 'he', 'lr': 0.040862465869591504, 'optimizer': 'adamw', 'weight_decay': 2.44430691912296e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 108}. Best is trial 79 with value: -4.038172245025635.
# [I 2026-09-15 14:06:05,106] Trial 80 finished with value: -3.595576524734497 and parameters: {'n_hidden_layers': 2, 'activation': 'gelu', 'dropout': 0.40559057064128684, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04225228648387923, 'optimizer': 'adamw', 'weight_decay': 3.316871946540248e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 110, 'hidden_dim_1': 254}. Best is trial 79 with value: -4.038172245025635.
# [I 2026-09-15 14:06:28,211] Trial 81 finished with value: -3.8873696327209473 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.3737249143901971, 'layernorm': False, 'weight_init': 'he', 'lr': 0.03255984047859681, 'optimizer': 'adamw', 'weight_decay': 2.592778661890862e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 124}. Best is trial 79 with value: -4.038172245025635.
# [I 2026-09-15 14:06:51,576] Trial 82 finished with value: -4.037883281707764 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.256325225263054, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04061152105124181, 'optimizer': 'adamw', 'weight_decay': 2.3459416230242662e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 98}. Best is trial 79 with value: -4.038172245025635.
# [I 2026-09-15 14:07:15,719] Trial 83 finished with value: 1.8209184408187866 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.2672650600927429, 'layernorm': False, 'weight_init': 'he', 'lr': 0.00020655830144120533, 'optimizer': 'adamw', 'weight_decay': 2.386455146129563e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 83}. Best is trial 79 with value: -4.038172245025635.
# [I 2026-09-15 14:07:38,910] Trial 84 finished with value: -4.040943622589111 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.22100362585309702, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04044600853234833, 'optimizer': 'adamw', 'weight_decay': 6.49255452142032e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 99}. Best is trial 84 with value: -4.040943622589111.
# [I 2026-09-15 14:08:02,339] Trial 85 finished with value: -3.0987422466278076 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.2251846438496938, 'layernorm': False, 'weight_init': 'he', 'lr': 0.025544355172274935, 'optimizer': 'adamw', 'weight_decay': 7.157300094181309e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 96}. Best is trial 84 with value: -4.040943622589111.
# [I 2026-09-15 14:08:25,532] Trial 86 finished with value: -4.09634256362915 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.24631444355968654, 'layernorm': False, 'weight_init': 'he', 'lr': 0.042034293650837974, 'optimizer': 'adamw', 'weight_decay': 5.826582812584563e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 106}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:08:48,571] Trial 87 finished with value: 1.4108487367630005 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.2739657490209357, 'layernorm': False, 'weight_init': 'he', 'lr': 0.0031113522167132935, 'optimizer': 'adamw', 'weight_decay': 5.723802635421041e-05, 'gradient_clip': 0.1, 'patience': 10, 'hidden_dim_0': 102}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:09:12,181] Trial 88 finished with value: -4.034184455871582 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.24516946026653585, 'layernorm': False, 'weight_init': 'he', 'lr': 0.0416126716634497, 'optimizer': 'adamw', 'weight_decay': 6.550102035071446e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 86}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:09:35,965] Trial 89 finished with value: -4.037474155426025 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.23379508880367678, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04293758363445353, 'optimizer': 'adamw', 'weight_decay': 6.670145074410935e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 84}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:09:59,782] Trial 90 finished with value: -4.055126667022705 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.2111365812647335, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04212407608347483, 'optimizer': 'adamw', 'weight_decay': 6.570556777980941e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 87}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:10:22,979] Trial 91 finished with value: -3.991204261779785 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.20292659477456415, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04109105792551535, 'optimizer': 'adamw', 'weight_decay': 6.308187835847391e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 86}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:10:45,498] Trial 92 finished with value: -3.6802186965942383 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.25401912061380616, 'layernorm': False, 'weight_init': 'he', 'lr': 0.030323600054039335, 'optimizer': 'adamw', 'weight_decay': 6.719444105012383e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 77}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:11:08,617] Trial 93 finished with value: -4.038482189178467 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.23912625765430504, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04403724843283113, 'optimizer': 'adamw', 'weight_decay': 7.70028951672014e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 106}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:11:31,125] Trial 94 finished with value: -4.0271992683410645 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.23885502369085915, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04300551693878807, 'optimizer': 'adamw', 'weight_decay': 7.790739950596471e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 88}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:11:53,946] Trial 95 finished with value: -3.892839193344116 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.24075285092744847, 'layernorm': False, 'weight_init': 'he', 'lr': 0.031684611464080026, 'optimizer': 'adamw', 'weight_decay': 8.151429675701895e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 82}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:12:16,863] Trial 96 finished with value: -4.012073993682861 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.23667379280926237, 'layernorm': False, 'weight_init': 'he', 'lr': 0.0443611550264216, 'optimizer': 'adamw', 'weight_decay': 7.52997788716303e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 89}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:12:39,639] Trial 97 finished with value: -2.4126076698303223 and parameters: {'n_hidden_layers': 1, 'activation': 'elu', 'dropout': 0.21911427122798824, 'layernorm': False, 'weight_init': 'he', 'lr': 0.022104588424653005, 'optimizer': 'adamw', 'weight_decay': 5.878344736431152e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 106}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:13:03,122] Trial 98 finished with value: -4.038166522979736 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.2069971030479212, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04310827365690366, 'optimizer': 'adamw', 'weight_decay': 7.039195163315139e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 98}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:13:25,980] Trial 99 finished with value: -3.8790829181671143 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.17562992373030925, 'layernorm': False, 'weight_init': 'he', 'lr': 0.03331686837989739, 'optimizer': 'adamw', 'weight_decay': 5.3193933416423565e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 100}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:13:49,873] Trial 100 finished with value: -3.2497425079345703 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.20925676094980258, 'layernorm': False, 'weight_init': 'he', 'lr': 0.026392427610920734, 'optimizer': 'adamw', 'weight_decay': 7.190162865310034e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 73}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:14:13,888] Trial 101 finished with value: -4.062102794647217 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.2424037637891721, 'layernorm': False, 'weight_init': 'he', 'lr': 0.042959498409477326, 'optimizer': 'adamw', 'weight_decay': 7.9155770891195e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 95}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:14:35,522] Trial 102 finished with value: -4.015132904052734 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.2468887150151372, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04384713241140237, 'optimizer': 'adamw', 'weight_decay': 8.134829122491382e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 97}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:14:54,642] Trial 103 finished with value: -3.9475061893463135 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.2655591245492326, 'layernorm': False, 'weight_init': 'he', 'lr': 0.0453332904523973, 'optimizer': 'adamw', 'weight_decay': 7.703060914494523e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 89}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:15:16,837] Trial 104 finished with value: -4.045223712921143 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.22967175870222403, 'layernorm': False, 'weight_init': 'he', 'lr': 0.049950658550284216, 'optimizer': 'adamw', 'weight_decay': 8.96998930765757e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 81}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:15:39,408] Trial 105 finished with value: -3.615431547164917 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.18205495599294635, 'layernorm': False, 'weight_init': 'he', 'lr': 0.03410942287993386, 'optimizer': 'adamw', 'weight_decay': 9.31256429806049e-05, 'gradient_clip': 0.1, 'patience': 10, 'hidden_dim_0': 82}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:16:02,108] Trial 106 finished with value: -3.4674201011657715 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.23069907595369277, 'layernorm': False, 'weight_init': 'he', 'lr': 0.02801673209352755, 'optimizer': 'adamw', 'weight_decay': 8.724667912430529e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 92}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:16:19,475] Trial 107 finished with value: -3.930760145187378 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.21199871257008554, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04992113977978659, 'optimizer': 'adamw', 'weight_decay': 6.427071321001765e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 105}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:16:42,450] Trial 108 finished with value: 1.6875380277633667 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.28258031110489357, 'layernorm': False, 'weight_init': 'he', 'lr': 0.0011588867264466412, 'optimizer': 'adamw', 'weight_decay': 6.951809104650307e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 68}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:17:06,724] Trial 109 finished with value: -3.519674062728882 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.19768062401904188, 'layernorm': False, 'weight_init': 'he', 'lr': 0.028583381671659188, 'optimizer': 'adamw', 'weight_decay': 6.654090850289948e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 214}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:17:29,552] Trial 110 finished with value: -3.973083972930908 and parameters: {'n_hidden_layers': 1, 'activation': 'elu', 'dropout': 0.2599057032590646, 'layernorm': False, 'weight_init': 'he', 'lr': 0.03484881744383216, 'optimizer': 'adamw', 'weight_decay': 6.143763949766644e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 79}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:17:49,933] Trial 111 finished with value: -3.9380040168762207 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.24262177989012113, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04275477525255589, 'optimizer': 'adamw', 'weight_decay': 6.924588298472792e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 97}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:18:13,086] Trial 112 finished with value: -4.0147833824157715 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.23124920466681625, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04285657178759512, 'optimizer': 'adamw', 'weight_decay': 9.857830176676317e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 87}. Best is trial 86 with value: -4.09634256362915.
# [I 2026-09-15 14:18:35,880] Trial 113 finished with value: -3.937666893005371 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.2996560477711805, 'layernorm': False, 'weight_init': 'he', 'lr': 0.03390907673153711, 'optimizer': 'adamw', 'weight_decay': 7.903430602247383e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 94}. Best is trial 86 with value: -4.09634256362915.
# ...
# [I 2026-09-15 17:11:50,084] Trial 72 finished with value: -3.863898754119873 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.09023445723918999, 'layernorm': False, 'weight_init': 'he', 'lr': 0.03163217841050096, 'optimizer': 'adam', 'weight_decay': 9.736759061181639e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 127}. Best is trial 25 with value: -4.1909966468811035.
# [I 2026-09-15 17:12:11,810] Trial 73 finished with value: -4.196106433868408 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.10967191872882048, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04335292122183034, 'optimizer': 'adam', 'weight_decay': 4.743861644399042e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 108}. Best is trial 73 with value: -4.196106433868408.
# [I 2026-09-15 17:12:34,106] Trial 74 finished with value: -4.137974739074707 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.1054117559513082, 'layernorm': False, 'weight_init': 'he', 'lr': 0.043455153250473534, 'optimizer': 'adam', 'weight_decay': 4.99156991675099e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 109}. Best is trial 73 with value: -4.196106433868408.
# [I 2026-09-15 17:12:53,706] Trial 75 finished with value: -4.044801235198975 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.06840558462493015, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04376942975710049, 'optimizer': 'adam', 'weight_decay': 4.856944515977548e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 142}. Best is trial 73 with value: -4.196106433868408.
# [I 2026-09-15 17:13:15,553] Trial 76 finished with value: -4.214630126953125 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.07137677580990837, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04287028852780279, 'optimizer': 'adam', 'weight_decay': 4.797083967416108e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 146}. Best is trial 76 with value: -4.214630126953125.
# [I 2026-09-15 17:13:38,817] Trial 77 finished with value: -3.5852949619293213 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.059422428915394364, 'layernorm': False, 'weight_init': 'he', 'lr': 0.025876998515982623, 'optimizer': 'adamw', 'weight_decay': 5.00935676346601e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 142}. Best is trial 76 with value: -4.214630126953125.
# [I 2026-09-15 17:13:58,038] Trial 78 finished with value: -3.957770824432373 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.043901398090323306, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04349202614756617, 'optimizer': 'adam', 'weight_decay': 4.760758557571645e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 159}. Best is trial 76 with value: -4.214630126953125.
# [I 2026-09-15 17:14:21,220] Trial 79 finished with value: -4.071348667144775 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.0184287171043699, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.04135909337797821, 'optimizer': 'adam', 'weight_decay': 4.439730056551836e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 133}. Best is trial 76 with value: -4.214630126953125.
# [I 2026-09-15 17:14:43,996] Trial 80 finished with value: -1.9878627061843872 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.014705044226200215, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.01634067269872196, 'optimizer': 'adam', 'weight_decay': 4.143392890925037e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 134}. Best is trial 76 with value: -4.214630126953125.
# [I 2026-09-15 17:15:07,447] Trial 81 finished with value: -4.139396667480469 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.07541164871993511, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.04396598315760249, 'optimizer': 'adam', 'weight_decay': 4.482286851046845e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 128}. Best is trial 76 with value: -4.214630126953125.
# [I 2026-09-15 17:15:27,383] Trial 82 finished with value: -3.9756665229797363 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.07814681965020112, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.044217474405787605, 'optimizer': 'adam', 'weight_decay': 4.535850504453257e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 129}. Best is trial 76 with value: -4.214630126953125.
# [I 2026-09-15 17:15:49,913] Trial 83 finished with value: -3.778036117553711 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.0985723315955174, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.037899080981462316, 'optimizer': 'adam', 'weight_decay': 5.2842130066452576e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 146}. Best is trial 76 with value: -4.214630126953125.
# [I 2026-09-15 17:16:13,033] Trial 84 finished with value: -3.0285449028015137 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.054311730175307785, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.02558565616449655, 'optimizer': 'adam', 'weight_decay': 5.788860564202267e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 166}. Best is trial 76 with value: -4.214630126953125.
# [I 2026-09-15 17:16:35,622] Trial 85 finished with value: -3.9057986736297607 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.022280560345351884, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.04463006945095008, 'optimizer': 'adam', 'weight_decay': 3.6682378130125876e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 119}. Best is trial 76 with value: -4.214630126953125.
# [I 2026-09-15 17:16:58,146] Trial 86 finished with value: -3.8311662673950195 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.07731959928100579, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.0359485130799273, 'optimizer': 'adam', 'weight_decay': 4.258099224196479e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 137}. Best is trial 76 with value: -4.214630126953125.
# [I 2026-09-15 17:17:21,063] Trial 87 finished with value: -3.1872458457946777 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.111851827597197, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.02892003640322855, 'optimizer': 'adam', 'weight_decay': 5.105405634051095e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 158}. Best is trial 76 with value: -4.214630126953125.
# [I 2026-09-15 17:17:43,593] Trial 88 finished with value: -4.137942314147949 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.0336994124714406, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.04973653428993075, 'optimizer': 'adam', 'weight_decay': 4.5160004149727804e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 125}. Best is trial 76 with value: -4.214630126953125.
# [I 2026-09-15 17:18:06,203] Trial 89 finished with value: -4.252732276916504 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.006143223249640848, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.049893904674990164, 'optimizer': 'adam', 'weight_decay': 4.7769055689175015e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 147}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 17:18:29,432] Trial 90 finished with value: -4.079562187194824 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.0054785410926848875, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.04960563110158681, 'optimizer': 'adamw', 'weight_decay': 4.530844944518659e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 148}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 17:18:52,745] Trial 91 finished with value: -4.067605495452881 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.02771152323656044, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.04868170951798334, 'optimizer': 'adamw', 'weight_decay': 4.6579441893612145e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 175}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 17:19:15,542] Trial 92 finished with value: -3.8696160316467285 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.0015323637897553593, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.037799561829879376, 'optimizer': 'adamw', 'weight_decay': 4.384011669461379e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 150}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 17:19:38,814] Trial 93 finished with value: -3.929241418838501 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.034314627958797, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.041162858992407056, 'optimizer': 'adamw', 'weight_decay': 4.028383967326982e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 124}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 17:20:01,818] Trial 94 finished with value: -4.165855407714844 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.01689766681661045, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.049626508842326014, 'optimizer': 'adamw', 'weight_decay': 5.5711669056555196e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 108}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 17:20:24,592] Trial 95 finished with value: -3.3095076084136963 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.0073346396901876046, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.028410982725396144, 'optimizer': 'adamw', 'weight_decay': 5.4216070876839564e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 100}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 17:20:47,553] Trial 96 finished with value: -4.111353397369385 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.04412193837668655, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.04928070648833065, 'optimizer': 'adamw', 'weight_decay': 5.6632454845030735e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 108}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 17:21:10,540] Trial 97 finished with value: -2.5390515327453613 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.05335267563631428, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.020475409476253592, 'optimizer': 'adamw', 'weight_decay': 5.733842102424958e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 109}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 17:21:33,634] Trial 98 finished with value: -3.5365078449249268 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.04818639820534036, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.03428854733583204, 'optimizer': 'adamw', 'weight_decay': 3.78780996540758e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 107}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 17:30:44,401] Trial 122 finished with value: -4.003779411315918 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.01780747588839311, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.04425163410477732, 'optimizer': 'adamw', 'weight_decay': 4.328570160679408e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 112}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 17:41:18,729] Trial 123 finished with value: -3.586674690246582 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.03851203001417182, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.04936096892153118, 'optimizer': 'adamw', 'weight_decay': 5.025325047980651e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 121}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 18:03:26,269] Trial 124 finished with value: -3.8898463249206543 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.08580533999599818, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.03966070431612355, 'optimizer': 'adamw', 'weight_decay': 4.1717085339716854e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 103}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 18:03:50,105] Trial 125 finished with value: -3.4414758682250977 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.11473796460176987, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.03556704389247525, 'optimizer': 'adam', 'weight_decay': 4.7061214834457294e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 131}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 18:04:16,064] Trial 126 finished with value: -4.056347370147705 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.40885333815796326, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.044096942626340105, 'optimizer': 'adamw', 'weight_decay': 3.863713770516445e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 116}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 18:24:46,943] Trial 127 finished with value: -3.8061931133270264 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.023035099848282767, 'layernorm': False, 'weight_init': 'he', 'lr': 0.031409545691003425, 'optimizer': 'adam', 'weight_decay': 4.472181223527566e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 140}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 18:40:12,457] Trial 128 finished with value: -4.0148210525512695 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.05611139747079369, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.04042662771408252, 'optimizer': 'adam', 'weight_decay': 5.197833545126201e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 107}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 18:55:14,334] Trial 129 finished with value: 0.9959191679954529 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.10107711647139112, 'layernorm': False, 'weight_init': 'he', 'lr': 0.0018268002560969136, 'optimizer': 'adamw', 'weight_decay': 5.447677099244546e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 124}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 19:10:39,120] Trial 130 finished with value: -3.085287570953369 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.03804323120908402, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.02746204022164363, 'optimizer': 'adam', 'weight_decay': 4.877921237522101e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 91}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 19:26:02,636] Trial 131 finished with value: -4.149954795837402 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.0091901223260956, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.048044467439096655, 'optimizer': 'adamw', 'weight_decay': 4.595196018551756e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 146}. Best is trial 89 with value: -4.252732276916504.
# [I 2026-09-15 19:32:06,520] Trial 132 finished with value: -4.107117176055908 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.029248699053243864, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.049954124346526865, 'optimizer': 'adamw', 'weight_decay': 4.151138904893701e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 161}. Best is trial 89 with value: -4.252732276916504.
