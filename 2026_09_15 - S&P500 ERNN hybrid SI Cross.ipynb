# %% [markdown]
# # SPY Hybrid ERNN SI Cross-lagged
#
# Original unrestricted model tuning with seven separately estimated nominal levels and the Bitcoin rank-based selection procedure.

# %%
# ============================================================
# SPY MODELLING DATA PREPARATION
# Common setup for all ERNN and QRNN specifications
# ============================================================

from pathlib import Path
import random
import numpy as np
import pandas as pd
import torch


# ------------------------------------------------------------
# 1. Reproducibility and device
# ------------------------------------------------------------

BASE_SEED = 2026

random.seed(BASE_SEED)
np.random.seed(BASE_SEED)
torch.manual_seed(BASE_SEED)

if torch.cuda.is_available():
    torch.cuda.manual_seed_all(BASE_SEED)

device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

print("Device:", device)


# ------------------------------------------------------------
# 2. Load the scaled SPY dataset
# ------------------------------------------------------------

DATA_PATH = Path.home() / "SPY_features_scaled.csv"

df = pd.read_csv(
    DATA_PATH,
    index_col="Date",
    parse_dates=True
)

df = (
    df
    .sort_index()
    .drop_duplicates()
    .dropna()
    .copy()
)


# ------------------------------------------------------------
# 3. Response and predictors
# ------------------------------------------------------------

target_col = "log_return"

feature_cols = [
    "Volatility",
    "RSI_14",
    "ATR_14",
    "QQQ_LogReturns",
    "VIX_LogChange",
    "Volume_LogChange",
]

required_cols = [target_col] + feature_cols

missing_cols = [
    column
    for column in required_cols
    if column not in df.columns
]

if missing_cols:
    raise ValueError(
        "Missing required columns: "
        + ", ".join(missing_cols)
    )


# ------------------------------------------------------------
# 4. Chronological 70%-15%-15% split
# ------------------------------------------------------------

train_size = int(len(df) * 0.70)
val_size = int(len(df) * 0.15)

train_df = df.iloc[:train_size].copy()
val_df = df.iloc[train_size:train_size + val_size].copy()
test_df = df.iloc[train_size + val_size:].copy()


# ------------------------------------------------------------
# 5. Convert samples to tensors
# ------------------------------------------------------------

def dataframe_to_tensors(sample):
    X = torch.tensor(
        sample[feature_cols].to_numpy(),
        dtype=torch.float32,
        device=device
    )
    y = torch.tensor(
        sample[target_col].to_numpy(),
        dtype=torch.float32,
        device=device
    )
    return X, y


X_train, y_train = dataframe_to_tensors(train_df)
X_val, y_val = dataframe_to_tensors(val_df)
X_test, y_test = dataframe_to_tensors(test_df)

# Compatibility aliases used by later QRNN cells.
X_test_q = X_test
y_test_q = y_test

levels = [
    0.025,
    0.050,
    0.250,
    0.500,
    0.750,
    0.950,
    0.975,
]

alpha_levels = levels
tau_levels = levels


# ------------------------------------------------------------
# 6. Checks and split summary
# ------------------------------------------------------------

assert len(X_train) == len(y_train)
assert len(X_val) == len(y_val)
assert len(X_test) == len(y_test)
assert X_train.shape[1] == len(feature_cols)
assert torch.isfinite(X_train).all()
assert torch.isfinite(X_val).all()
assert torch.isfinite(X_test).all()
assert torch.isfinite(y_train).all()
assert torch.isfinite(y_val).all()
assert torch.isfinite(y_test).all()

split_summary = pd.DataFrame({
    "Sample": ["Training", "Validation", "Test"],
    "Observations": [len(train_df), len(val_df), len(test_df)],
    "Start": [
        train_df.index.min().date(),
        val_df.index.min().date(),
        test_df.index.min().date(),
    ],
    "End": [
        train_df.index.max().date(),
        val_df.index.max().date(),
        test_df.index.max().date(),
    ],
})

display(split_summary)

print("Input features:", feature_cols)
print("Number of predictors:", len(feature_cols))
print("X_train shape:", tuple(X_train.shape))
print("X_val shape:  ", tuple(X_val.shape))
print("X_test shape: ", tuple(X_test.shape))
# Out:
# Device: cpu
#        Sample  Observations       Start         End
# 0    Training          2219  2014-01-23  2022-11-11
# 1  Validation           475  2022-11-14  2024-10-04
# 2        Test           476  2024-10-07  2026-08-31
# Input features: ['Volatility', 'RSI_14', 'ATR_14', 'QQQ_LogReturns', 'VIX_LogChange', 'Volume_LogChange']
# Number of predictors: 6
# X_train shape: (2219, 6)
# X_val shape:   (475, 6)
# X_test shape:  (476, 6)

# %% [markdown]
# ## Original tuning
#
# Run this cell after the SPY data-preparation cell.

# %%
# ============================================================
# ORIGINAL TUNING — SPY HYBRID ERNN SI CROSS-LAGGED
# Seven separately estimated nominal levels
# 200 Optuna trials per level
# ============================================================

import copy
import json
import time

import optuna
import torch.nn as nn
import torch.nn.functional as F
from optuna.samplers import TPESampler


MODEL_NAME = "spy_ernn_si_cross"
FORM = "SI"
LAG_TYPE = "cross"
N_TRIALS = 200
MAX_EPOCHS = 200

TAU_LEVELS = [
    0.025,
    0.050,
    0.250,
    0.500,
    0.750,
    0.950,
    0.975,
]

OUTPUT_DIR = Path("spy_original_tuning_results") / MODEL_NAME
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print("Model:", MODEL_NAME)
print("Output directory:", OUTPUT_DIR.resolve())


# ------------------------------------------------------------
# 1. Reproducibility
# ------------------------------------------------------------

def set_model_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


# ------------------------------------------------------------
# 2. AGD negative log-likelihood
# ------------------------------------------------------------

def hybrid_ernn_loss(y, expectile_forecast, sigma, tau):
    """Mean asymmetric-Gaussian negative log-likelihood."""

    eps = torch.finfo(expectile_forecast.dtype).eps
    sigma = torch.clamp(sigma, min=eps)

    tau_tensor = torch.as_tensor(
        tau,
        dtype=expectile_forecast.dtype,
        device=expectile_forecast.device,
    )

    difference = y - expectile_forecast

    asymmetric_squared_error = (
        torch.abs(
            tau_tensor
            - (difference < 0).to(expectile_forecast.dtype)
        )
        * difference.pow(2)
    )

    pi_tensor = torch.as_tensor(
        torch.pi,
        dtype=expectile_forecast.dtype,
        device=expectile_forecast.device,
    )

    normalising_constant = (
        torch.log(
            torch.sqrt(pi_tensor / tau_tensor)
            + torch.sqrt(pi_tensor / (1.0 - tau_tensor))
        )
        - torch.log(
            torch.as_tensor(
                2.0,
                dtype=expectile_forecast.dtype,
                device=expectile_forecast.device,
            )
        )
    )

    observation_nll = (
        torch.log(sigma)
        + normalising_constant
        + asymmetric_squared_error / sigma.pow(2)
    )

    return observation_nll.mean()


# ------------------------------------------------------------
# 3. CARE-hybrid recursion
# ------------------------------------------------------------

def compute_hybrid_location(
    y,
    X,
    gamma1,
    gamma2,
    gamma3,
    fnn,
    psi,
):
    """SI-form cross-lagged CARE-hybrid recursion."""

    fnn_output = fnn(X).squeeze(-1)
    zero_value = y.new_zeros(())

    care_forecasts = [zero_value]
    hybrid_forecasts = [zero_value]

    for time_index in range(1, len(y)):
        previous_return = y[time_index - 1]

        previous_state = hybrid_forecasts[time_index - 1]
        absolute_return = torch.abs(previous_return)
        care_value = (
            gamma1 * previous_state
            + gamma2 * absolute_return
            + gamma3 * previous_state * absolute_return
        )

        hybrid_value = (
            psi * care_value
            + (1.0 - psi) * fnn_output[time_index]
        )

        care_forecasts.append(care_value)
        hybrid_forecasts.append(hybrid_value)

    return (
        torch.stack(hybrid_forecasts),
        torch.stack(care_forecasts),
    )


# ------------------------------------------------------------
# 4. Hybrid ERNN model
# ------------------------------------------------------------

class HybridERNN_SI_Cross(nn.Module):
    def __init__(self, input_dim, config):
        super().__init__()

        self.eps = 1e-6

        self.gamma1_raw = nn.Parameter(
            torch.tensor(1.386)
        )

        self.gamma2_raw = nn.Parameter(
            torch.tensor(0.3)
        )

        self.gamma3_raw = nn.Parameter(
            torch.tensor(0.3)
        )
        self.psi_raw = nn.Parameter(
            torch.tensor(0.0)
        )

        self.sigma_raw = nn.Parameter(
            torch.tensor(0.5)
        )

        layers = []
        previous_dimension = input_dim

        for layer_index in range(config["n_hidden_layers"]):
            hidden_dimension = config[f"hidden_dim_{layer_index}"]

            layers.append(
                nn.Linear(previous_dimension, hidden_dimension)
            )

            if config["layernorm"]:
                layers.append(nn.LayerNorm(hidden_dimension))

            layers.append(
                self.get_activation(config["activation"])
            )

            if config["dropout"] > 0:
                layers.append(nn.Dropout(config["dropout"]))

            previous_dimension = hidden_dimension

        layers.append(nn.Linear(previous_dimension, 1))
        self.fnn = nn.Sequential(*layers)

        self.initialise_weights(config["weight_init"])

    @staticmethod
    def get_activation(name):
        return {
            "relu": nn.ReLU(),
            "elu": nn.ELU(),
            "gelu": nn.GELU(),
            "tanh": nn.Tanh(),
        }[name]

    def initialise_weights(self, method):
        for module in self.fnn.modules():
            if not isinstance(module, nn.Linear):
                continue

            if method == "glorot":
                nn.init.xavier_uniform_(module.weight)
            else:
                nn.init.kaiming_uniform_(module.weight)

            if module.bias is not None:
                nn.init.zeros_(module.bias)

    def forward(self, y, X):
        gamma1 = torch.sigmoid(self.gamma1_raw)
        gamma2 = F.softplus(self.gamma2_raw)

        gamma3 = F.softplus(
            self.gamma3_raw
        )
        psi = torch.sigmoid(self.psi_raw)
        sigma = F.softplus(self.sigma_raw) + self.eps

        hybrid_forecast, care_forecast = compute_hybrid_location(
            y=y,
            X=X,
            gamma1=gamma1,
            gamma2=gamma2,
            gamma3=gamma3,
            fnn=self.fnn,
            psi=psi,
        )

        return hybrid_forecast, sigma, care_forecast


# ------------------------------------------------------------
# 5. Original Bitcoin coverage-ratio ranking diagnostic
# ------------------------------------------------------------

def calculate_crp(y, forecast, tau):
    if tau <= 0.5:
        empirical_probability = (
            y <= forecast
        ).float().mean().item()
        target_probability = tau
    else:
        empirical_probability = (
            y > forecast
        ).float().mean().item()
        target_probability = 1.0 - tau

    crp = empirical_probability / target_probability
    crp_penalty = (crp - 1.0) ** 2

    return crp, crp_penalty, empirical_probability


# ------------------------------------------------------------
# 6. Optuna search space
# ------------------------------------------------------------

def suggest_ernn_config(trial):
    config = {
        "n_hidden_layers": trial.suggest_int(
            "n_hidden_layers", 1, 3
        ),
        "activation": trial.suggest_categorical(
            "activation", ["relu", "elu", "gelu", "tanh"]
        ),
        "dropout": trial.suggest_float(
            "dropout", 0.0, 0.5
        ),
        "layernorm": trial.suggest_categorical(
            "layernorm", [True, False]
        ),
        "weight_init": trial.suggest_categorical(
            "weight_init", ["glorot", "he"]
        ),
        "lr": trial.suggest_float(
            "lr", 1e-4, 5e-2, log=True
        ),
        "optimizer": trial.suggest_categorical(
            "optimizer", ["adam", "adamw"]
        ),
        "weight_decay": trial.suggest_float(
            "weight_decay", 0.0, 1e-4
        ),
        "gradient_clip": trial.suggest_categorical(
            "gradient_clip", [0.1, 1.0, 5.0]
        ),
        "patience": trial.suggest_categorical(
            "patience", [10, 20, 30]
        ),
    }

    for layer_index in range(config["n_hidden_layers"]):
        config[f"hidden_dim_{layer_index}"] = trial.suggest_int(
            f"hidden_dim_{layer_index}", 32, 256
        )

    return config


def make_optimizer(model, config):
    arguments = {
        "params": model.parameters(),
        "lr": config["lr"],
        "weight_decay": config["weight_decay"],
    }

    if config["optimizer"] == "adam":
        return torch.optim.Adam(**arguments)

    return torch.optim.AdamW(**arguments)


# ------------------------------------------------------------
# 7. Fit one trial configuration
# ------------------------------------------------------------

def train_ernn_configuration(config, tau, model_seed=BASE_SEED):
    set_model_seed(model_seed)

    model = HybridERNN_SI_Cross(
        input_dim=X_train.shape[1],
        config=config,
    ).to(device)

    optimizer = make_optimizer(model, config)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode="min",
        patience=10,
        factor=0.5,
        min_lr=1e-6,
    )

    best_validation_nll = np.inf
    best_model_state = None
    patience_counter = 0
    epochs_completed = 0

    for epoch in range(MAX_EPOCHS):
        epochs_completed = epoch + 1

        model.train()
        optimizer.zero_grad()

        train_forecast, train_sigma, _ = model(y_train, X_train)

        train_loss = hybrid_ernn_loss(
            y=y_train,
            expectile_forecast=train_forecast,
            sigma=train_sigma,
            tau=tau,
        )

        if not torch.isfinite(train_loss):
            return None

        train_loss.backward()

        nn.utils.clip_grad_norm_(
            model.parameters(),
            config["gradient_clip"],
        )

        optimizer.step()

        model.eval()

        with torch.no_grad():
            validation_forecast, validation_sigma, _ = model(
                y_val,
                X_val,
            )

            validation_loss = hybrid_ernn_loss(
                y=y_val,
                expectile_forecast=validation_forecast,
                sigma=validation_sigma,
                tau=tau,
            )

        if not torch.isfinite(validation_loss):
            return None

        scheduler.step(validation_loss)
        current_validation_nll = validation_loss.item()

        if current_validation_nll < best_validation_nll:
            best_validation_nll = current_validation_nll
            best_model_state = copy.deepcopy(model.state_dict())
            patience_counter = 0
        else:
            patience_counter += 1

            if patience_counter >= config["patience"]:
                break

    if best_model_state is None:
        return None

    model.load_state_dict(best_model_state)
    model.eval()

    with torch.no_grad():
        validation_forecast, validation_sigma, _ = model(y_val, X_val)

        validation_nll = hybrid_ernn_loss(
            y=y_val,
            expectile_forecast=validation_forecast,
            sigma=validation_sigma,
            tau=tau,
        ).item()

        (
            validation_crp,
            validation_crp_penalty,
            validation_hit_rate,
        ) = calculate_crp(
            y=y_val,
            forecast=validation_forecast,
            tau=tau,
        )

    parameters = {
        "gamma1": torch.sigmoid(model.gamma1_raw).item(),
        "gamma2": F.softplus(model.gamma2_raw).item(),
        "gamma3": F.softplus(model.gamma3_raw).item(),
        "psi": torch.sigmoid(model.psi_raw).item(),
        "sigma": (F.softplus(model.sigma_raw) + model.eps).item(),
    }

    return {
        "model": model,
        "validation_nll": validation_nll,
        "validation_crp": validation_crp,
        "validation_crp_penalty": validation_crp_penalty,
        "validation_hit_rate": validation_hit_rate,
        "epochs_completed": epochs_completed,
        **parameters,
    }


# ------------------------------------------------------------
# 8. Optuna objective and rank-based selection
# ------------------------------------------------------------

def objective_ernn(trial, tau):
    config = suggest_ernn_config(trial)
    result = train_ernn_configuration(config, tau)

    if result is None:
        raise optuna.TrialPruned(
            "Non-finite loss or no valid checkpoint."
        )

    for name in [
        "validation_nll",
        "validation_crp",
        "validation_crp_penalty",
        "validation_hit_rate",
        "epochs_completed",
        "gamma1",
        "gamma2",
        "gamma3",
        "psi",
        "sigma",
    ]:
        trial.set_user_attr(name, result[name])

    return result["validation_nll"]


def rank_completed_trials(study):
    completed_trials = [
        trial
        for trial in study.trials
        if (
            trial.state == optuna.trial.TrialState.COMPLETE
            and trial.value is not None
            and np.isfinite(trial.value)
            and "validation_crp_penalty" in trial.user_attrs
        )
    ]

    if not completed_trials:
        raise RuntimeError("No valid completed Optuna trials.")

    nll_order = sorted(
        completed_trials,
        key=lambda trial: trial.user_attrs["validation_nll"],
    )

    crp_order = sorted(
        completed_trials,
        key=lambda trial: trial.user_attrs[
            "validation_crp_penalty"
        ],
    )

    nll_ranks = {
        trial.number: rank
        for rank, trial in enumerate(nll_order, start=1)
    }

    crp_ranks = {
        trial.number: rank
        for rank, trial in enumerate(crp_order, start=1)
    }

    ranking_records = []

    for trial in completed_trials:
        rank_nll = nll_ranks[trial.number]
        rank_crp = crp_ranks[trial.number]

        ranking_records.append({
            "trial": trial.number,
            **trial.user_attrs,
            "rank_nll": rank_nll,
            "rank_crp": rank_crp,
            "sum_rank": rank_nll + rank_crp,
            **trial.params,
        })

    ranking_table = pd.DataFrame(ranking_records)

    ranking_table = ranking_table.sort_values(
        [
            "sum_rank",
            "validation_nll",
            "validation_crp_penalty",
            "trial",
        ]
    ).reset_index(drop=True)

    selected_trial_number = int(ranking_table.iloc[0]["trial"])

    selected_trial = next(
        trial
        for trial in completed_trials
        if trial.number == selected_trial_number
    )

    return selected_trial, ranking_table


# ------------------------------------------------------------
# 9. Run 200 trials at each nominal level
# ------------------------------------------------------------

best_configs_spy_ernn_si_cross = {}
best_models_spy_ernn_si_cross = {}
summary_records = []

overall_start_time = time.time()

for level_index, tau in enumerate(TAU_LEVELS):
    level_start_time = time.time()
    sampler_seed = BASE_SEED + level_index

    print("\n" + "=" * 72)
    print(f"Tuning {MODEL_NAME} at tau={tau:.3f}")
    print(f"Trials={N_TRIALS} | sampler seed={sampler_seed}")
    print("=" * 72)

    study = optuna.create_study(
        direction="minimize",
        sampler=TPESampler(seed=sampler_seed),
        study_name=f"{MODEL_NAME}_tau_{tau:.3f}",
    )

    study.optimize(
        lambda trial, current_tau=tau: objective_ernn(
            trial,
            current_tau,
        ),
        n_trials=N_TRIALS,
        show_progress_bar=True,
        gc_after_trial=True,
    )

    selected_trial, ranking_table = rank_completed_trials(study)
    tau_label = f"{tau:.3f}"

    ranking_table.insert(0, "tau", tau)

    ranking_path = OUTPUT_DIR / (
        f"{MODEL_NAME}_ranking_tau_{tau_label}.csv"
    )

    ranking_table.to_csv(ranking_path, index=False)

    selected_config = selected_trial.params.copy()

    selected_result = train_ernn_configuration(
        selected_config,
        tau,
    )

    if selected_result is None:
        raise RuntimeError(
            f"Selected trial could not be reproduced for tau={tau}."
        )

    selected_model = selected_result["model"]

    checkpoint_path = OUTPUT_DIR / (
        f"{MODEL_NAME}_best_tau_{tau_label}.pt"
    )

    torch.save(
        {
            "model_name": MODEL_NAME,
            "asset": "SPY",
            "form": FORM,
            "lag_type": LAG_TYPE,
            "tau": tau,
            "selected_trial": selected_trial.number,
            "config": selected_config,
            "model_state_dict": {
                key: value.detach().cpu()
                for key, value in selected_model.state_dict().items()
            },
            "validation_nll": selected_result["validation_nll"],
            "validation_crp": selected_result["validation_crp"],
            "validation_crp_penalty": selected_result[
                "validation_crp_penalty"
            ],
            "validation_hit_rate": selected_result[
                "validation_hit_rate"
            ],
            "estimated_parameters": {
                name: selected_result[name]
                for name in [
                    "gamma1",
                    "gamma2",
                    "gamma3",
                    "psi",
                    "sigma",
                ]
            },
            "feature_cols": feature_cols,
            "number_of_trials": N_TRIALS,
            "base_seed": BASE_SEED,
            "sampler_seed": sampler_seed,
        },
        checkpoint_path,
    )

    selected_record = {
        **selected_config,
        "selected_trial": selected_trial.number,
        **{
            name: selected_result[name]
            for name in [
                "validation_nll",
                "validation_crp",
                "validation_crp_penalty",
                "validation_hit_rate",
                "gamma1",
                "gamma2",
                "gamma3",
                "psi",
                "sigma",
            ]
        },
    }

    best_configs_spy_ernn_si_cross[tau] = selected_record
    best_models_spy_ernn_si_cross[tau] = selected_model

    runtime_hours = (
        time.time() - level_start_time
    ) / 3600

    summary_records.append({
        "tau": tau,
        "selected_trial": selected_trial.number,
        "validation_nll": selected_result["validation_nll"],
        "validation_crp": selected_result["validation_crp"],
        "validation_crp_penalty": selected_result[
            "validation_crp_penalty"
        ],
        "validation_hit_rate": selected_result[
            "validation_hit_rate"
        ],
        "gamma1": selected_result["gamma1"],
        "gamma2": selected_result["gamma2"],
        "gamma3": selected_result["gamma3"],
        "psi": selected_result["psi"],
        "sigma": selected_result["sigma"],
        "valid_trials": len(ranking_table),
        "runtime_hours": runtime_hours,
    })

    print("\nTop 10 rank-based trials:")
    print(
        ranking_table[[
            "trial",
            "validation_nll",
            "validation_crp",
            "validation_crp_penalty",
            "rank_nll",
            "rank_crp",
            "sum_rank",
        ]].head(10).to_string(index=False)
    )

    print("\nSelected trial:", selected_trial.number)
    print(
        "Validation NLL:",
        f"{selected_result['validation_nll']:.8f}",
    )
    print(
        "Validation CRP:",
        f"{selected_result['validation_crp']:.8f}",
    )
    print("Ranking saved to:", ranking_path)
    print("Checkpoint saved to:", checkpoint_path)


summary_spy_ernn_si_cross = pd.DataFrame(summary_records)

summary_path = OUTPUT_DIR / f"{MODEL_NAME}_tuning_summary.csv"
summary_spy_ernn_si_cross.to_csv(summary_path, index=False)

config_path = OUTPUT_DIR / f"{MODEL_NAME}_selected_configs.json"

with open(config_path, "w") as configuration_file:
    json.dump(
        {
            f"{tau:.3f}": config
            for tau, config in best_configs_spy_ernn_si_cross.items()
        },
        configuration_file,
        indent=2,
    )

print("\n" + "=" * 72)
print("SPY ORIGINAL ERNN TUNING COMPLETED:", MODEL_NAME)
print("=" * 72)
display(summary_spy_ernn_si_cross)

print(
    "Total runtime (hours):",
    f"{(time.time() - overall_start_time) / 3600:.3f}",
)
print("Summary saved to:", summary_path)
print("Selected configurations saved to:", config_path)
# Out:
# [I 2026-09-15 13:36:04,888] A new study created in memory with name: spy_ernn_si_cross_tau_0.025
# Model: spy_ernn_si_cross
# Output directory: /Users/miaomiaochen/Desktop/PhD program/Project 1/spy_original_tuning_results/spy_ernn_si_cross
#
# ========================================================================
# Tuning spy_ernn_si_cross at tau=0.025
# Trials=200 | sampler seed=2026
# ========================================================================
#   0%|          | 0/200 [00:00<?, ?it/s]
# [I 2026-09-15 13:36:28,425] Trial 0 finished with value: 1.7644705772399902 and parameters: {'n_hidden_layers': 1, 'activation': 'elu', 'dropout': 0.49377524711883497, 'layernorm': False, 'weight_init': 'he', 'lr': 0.0006552020421842752, 'optimizer': 'adam', 'weight_decay': 8.940884610144999e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 38}. Best is trial 0 with value: 1.7644705772399902.
# [I 2026-09-15 13:36:52,460] Trial 1 finished with value: 0.7222949266433716 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.07458356653667625, 'layernorm': False, 'weight_init': 'he', 'lr': 0.006969178688110181, 'optimizer': 'adam', 'weight_decay': 2.574006001095316e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 102}. Best is trial 1 with value: 0.7222949266433716.
# [I 2026-09-15 13:36:54,944] Trial 2 finished with value: 1.8489595651626587 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.37112272198735796, 'layernorm': True, 'weight_init': 'he', 'lr': 0.00010150090104324205, 'optimizer': 'adam', 'weight_decay': 6.518207314586205e-05, 'gradient_clip': 0.1, 'patience': 20, 'hidden_dim_0': 164}. Best is trial 1 with value: 0.7222949266433716.
# [I 2026-09-15 13:37:18,902] Trial 3 finished with value: 1.5954521894454956 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.08410371275195383, 'layernorm': False, 'weight_init': 'he', 'lr': 0.0018347830260217095, 'optimizer': 'adamw', 'weight_decay': 1.0709415904194131e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 237}. Best is trial 1 with value: 0.7222949266433716.
# [I 2026-09-15 13:37:41,207] Trial 4 finished with value: 1.2283082008361816 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.04674566511461714, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.004179064253320389, 'optimizer': 'adam', 'weight_decay': 6.125656858808738e-05, 'gradient_clip': 5.0, 'patience': 20, 'hidden_dim_0': 104}. Best is trial 1 with value: 0.7222949266433716.
# [I 2026-09-15 13:37:43,869] Trial 5 finished with value: 1.8675835132598877 and parameters: {'n_hidden_layers': 2, 'activation': 'elu', 'dropout': 0.45911076747236795, 'layernorm': True, 'weight_init': 'he', 'lr': 0.0001416875352388753, 'optimizer': 'adam', 'weight_decay': 9.345394674549201e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 223, 'hidden_dim_1': 87}. Best is trial 1 with value: 0.7222949266433716.
# [I 2026-09-15 13:38:10,679] Trial 6 finished with value: 1.7641221284866333 and parameters: {'n_hidden_layers': 2, 'activation': 'elu', 'dropout': 0.38970064512862934, 'layernorm': True, 'weight_init': 'he', 'lr': 0.0006254792571683692, 'optimizer': 'adamw', 'weight_decay': 6.801313798751197e-05, 'gradient_clip': 0.1, 'patience': 10, 'hidden_dim_0': 218, 'hidden_dim_1': 178}. Best is trial 1 with value: 0.7222949266433716.
# [I 2026-09-15 13:38:15,731] Trial 7 finished with value: 1.847814917564392 and parameters: {'n_hidden_layers': 2, 'activation': 'gelu', 'dropout': 0.36032432475263065, 'layernorm': True, 'weight_init': 'he', 'lr': 0.00020173841324002415, 'optimizer': 'adam', 'weight_decay': 4.1767279869402754e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0': 154, 'hidden_dim_1': 109}. Best is trial 1 with value: 0.7222949266433716.
# [I 2026-09-15 13:38:17,236] Trial 8 finished with value: 1.8464564085006714 and parameters: {'n_hidden_layers': 3, 'activation': 'relu', 'dropout': 0.4362763457742629, 'layernorm': False, 'weight_init': 'he', 'lr': 0.0005717356849949265, 'optimizer': 'adamw', 'weight_decay': 9.916771691263823e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 79, 'hidden_dim_1': 56, 'hidden_dim_2': 37}. Best is trial 1 with value: 0.7222949266433716.
# [I 2026-09-15 13:38:19,926] Trial 9 finished with value: 1.8453950881958008 and parameters: {'n_hidden_layers': 3, 'activation': 'relu', 'dropout': 0.013151451801451775, 'layernorm': False, 'weight_init': 'he', 'lr': 0.00012716878126572782, 'optimizer': 'adam', 'weight_decay': 1.9095096534588543e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 51, 'hidden_dim_1': 132, 'hidden_dim_2': 126}. Best is trial 1 with value: 0.7222949266433716.
# [I 2026-09-15 13:38:42,676] Trial 10 finished with value: -3.8082432746887207 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.15097474024909283, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.037908135375982255, 'optimizer': 'adamw', 'weight_decay': 3.1379335590221484e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 119}. Best is trial 10 with value: -3.8082432746887207.
# [I 2026-09-15 13:39:06,163] Trial 11 finished with value: -3.549306631088257 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.16366513375091546, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.03402526330326022, 'optimizer': 'adamw', 'weight_decay': 3.117485972962536e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 121}. Best is trial 10 with value: -3.8082432746887207.
# [I 2026-09-15 13:39:29,276] Trial 12 finished with value: -3.990081310272217 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.19279633488923958, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.046620580362009216, 'optimizer': 'adamw', 'weight_decay': 3.4990129609403785e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 128}. Best is trial 12 with value: -3.990081310272217.
# [I 2026-09-15 13:39:54,775] Trial 13 finished with value: -3.3423056602478027 and parameters: {'n_hidden_layers': 2, 'activation': 'tanh', 'dropout': 0.23786332849750252, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.04229974646761679, 'optimizer': 'adamw', 'weight_decay': 4.3634634603570556e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 192, 'hidden_dim_1': 239}. Best is trial 12 with value: -3.990081310272217.
# [I 2026-09-15 13:40:17,908] Trial 14 finished with value: -1.1767277717590332 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.17542264147037007, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.016247339371683493, 'optimizer': 'adamw', 'weight_decay': 7.599168284062825e-07, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 132}. Best is trial 12 with value: -3.990081310272217.
# [I 2026-09-15 13:40:44,073] Trial 15 finished with value: -0.9332950115203857 and parameters: {'n_hidden_layers': 2, 'activation': 'tanh', 'dropout': 0.2754717932164122, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.016198403756051395, 'optimizer': 'adamw', 'weight_decay': 3.6091669365685415e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 180, 'hidden_dim_1': 242}. Best is trial 12 with value: -3.990081310272217.
# [I 2026-09-15 13:41:06,626] Trial 16 finished with value: -1.3934582471847534 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.17042674969881644, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.01725021139952443, 'optimizer': 'adamw', 'weight_decay': 4.984887925511083e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 75}. Best is trial 12 with value: -3.990081310272217.
# [I 2026-09-15 13:41:32,251] Trial 17 finished with value: -2.894671678543091 and parameters: {'n_hidden_layers': 3, 'activation': 'tanh', 'dropout': 0.28403198494904347, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.046646192138245494, 'optimizer': 'adamw', 'weight_decay': 1.3722887436408784e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 143, 'hidden_dim_1': 180, 'hidden_dim_2': 249}. Best is trial 12 with value: -3.990081310272217.
# [I 2026-09-15 13:41:55,804] Trial 18 finished with value: 0.679874062538147 and parameters: {'n_hidden_layers': 2, 'activation': 'gelu', 'dropout': 0.11622355342152524, 'layernorm': True, 'weight_init': 'glorot', 'lr': 0.007540162647618844, 'optimizer': 'adamw', 'weight_decay': 5.638805838779985e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0': 103, 'hidden_dim_1': 36}. Best is trial 12 with value: -3.990081310272217.
# [I 2026-09-15 13:42:18,856] Trial 19 finished with value: 1.5174076557159424 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.21730471203723295, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0
. Best is trial 12 with value: -3.990081310272217.
# [I 2026-09-15 13:49:54,904] Trial 38 finished with value: -3.079402208328247 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.035823025260551644, 'layernorm': True, 'weight_init': 'he', 'lr': 0.027983416512785436, 'optimizer': 'adam', 'weight_decay': 2.396364247365787e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 94}. Best is trial 12 with value: -3.990081310272217.
# [I 2026-09-15 13:50:21,210] Trial 39 finished with value: 0.41105738282203674 and parameters: {'n_hidden_layers': 2, 'activation': 'elu', 'dropout': 0.40312347954105443, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.00852564119814337, 'optimizer': 'adamw', 'weight_decay': 4.1655875617849434e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 198, 'hidden_dim_1': 145}. Best is trial 12 with value: -3.990081310272217.
# [I 2026-09-15 13:50:45,601] Trial 40 finished with value: -0.8914976716041565 and parameters: {'n_hidden_layers': 2, 'activation': 'tanh', 'dropout': 0.07640061972425351, 'layernorm': False, 'weight_init': 'he', 'lr': 0.017857440574780597, 'optimizer': 'adamw', 'weight_decay': 5.525335749473475e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 168, 'hidden_dim_1': 78}. Best is trial 12 with value: -3.990081310272217.
# [I 2026-09-15 13:51:09,272] Trial 41 finished with value: -3.5428638458251953 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.14824694440457598, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.03636621447810648, 'optimizer': 'adamw', 'weight_decay': 2.8679643054895907e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 111}. Best is trial 12 with value: -3.990081310272217.
# [I 2026-09-15 13:51:32,900] Trial 42 finished with value: -3.585254430770874 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.49851538564423464, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.03432573584595001, 'optimizer': 'adamw', 'weight_decay': 3.6388677866903456e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 154}. Best is trial 12 with value: -3.990081310272217.
# [I 2026-09-15 13:51:55,230] Trial 43 finished with value: -3.970621347427368 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.13280878838325902, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.04960566166966419, 'optimizer': 'adamw', 'weight_decay': 2.0309928840998573e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 112}. Best is trial 12 with value: -3.990081310272217.
# [I 2026-09-15 13:52:21,116] Trial 44 finished with value: 1.809950828552246 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.10017731815621216, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.0002787496968119477, 'optimizer': 'adamw', 'weight_decay': 1.3505674431134936e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 255}. Best is trial 12 with value: -3.990081310272217.
# [I 2026-09-15 13:52:44,696] Trial 45 finished with value: -4.086929798126221 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.05919716976425651, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04651664611254792, 'optimizer': 'adam', 'weight_decay': 2.076220663597462e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 109}. Best is trial 45 with value: -4.086929798126221.
# [I 2026-09-15 13:53:07,898] Trial 46 finished with value: -0.48561012744903564 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.04864745211983078, 'layernorm': True, 'weight_init': 'he', 'lr': 0.013953898964119235, 'optimizer': 'adam', 'weight_decay': 1.9787969647170722e-05, 'gradient_clip': 0.1, 'patience': 20, 'hidden_dim_0': 138}. Best is trial 45 with value: -4.086929798126221.
# [I 2026-09-15 13:53:30,590] Trial 47 finished with value: -2.6045186519622803 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.12393635914354434, 'layernorm': False, 'weight_init': 'he', 'lr': 0.02320410667021238, 'optimizer': 'adam', 'weight_decay': 4.992706448983753e-07, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 108}. Best is trial 45 with value: -4.086929798126221.
# [I 2026-09-15 13:53:54,083] Trial 48 finished with value: -3.361454963684082 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.024219208410569598, 'layernorm': False, 'weight_init': 'he', 'lr': 0.028126690462145474, 'optimizer': 'adam', 'weight_decay': 1.6459800050081e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 204}. Best is trial 45 with value: -4.086929798126221.
# [I 2026-09-15 13:54:21,809] Trial 49 finished with value: 0.947448194026947 and parameters: {'n_hidden_layers': 3, 'activation': 'gelu', 'dropout': 0.06316955173513238, 'layernorm': False, 'weight_init': 'he', 'lr': 0.00574231374640621, 'optimizer': 'adam', 'weight_decay': 5.541185301678476e-06, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 154, 'hidden_dim_1': 144, 'hidden_dim_2': 237}. Best is trial 45 with value: -4.086929798126221.
# [I 2026-09-15 13:54:46,064] Trial 50 finished with value: -3.1789186000823975 and parameters: {'n_hidden_layers': 2, 'activation': 'relu', 'dropout': 0.08995371771457691, 'layernorm': False, 'weight_init': 'he', 'lr': 0.039842430930780846, 'optimizer': 'adam', 'weight_decay': 2.0578370602347955e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 118, 'hidden_dim_1': 211}. Best is trial 45 with value: -4.086929798126221.
# [I 2026-09-15 13:55:08,726] Trial 51 finished with value: -3.94307017326355 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.13444386597520042, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.0489568746315004, 'optimizer': 'adamw', 'weight_decay': 2.844916833914686e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 66}. Best is trial 45 with value: -4.086929798126221.
# [I 2026-09-15 13:55:30,900] Trial 52 finished with value: -4.056956768035889 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.13618399056231165, 'layernorm': False, 'weight_init': 'he', 'lr': 0.
and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.19418653643644676, 'layernorm': False, 'weight_init': 'he', 'lr': 0.042637335780627277, 'optimizer': 'adamw', 'weight_decay': 4.3860086340517164e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 88}. Best is trial 45 with value: -4.086929798126221.
# [I 2026-09-15 14:16:03,325] Trial 106 finished with value: -4.072046279907227 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.18455435985208862, 'layernorm': False, 'weight_init': 'he', 'lr': 0.042548830596306625, 'optimizer': 'adamw', 'weight_decay': 4.5532503365349955e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 91}. Best is trial 45 with value: -4.086929798126221.
# [I 2026-09-15 14:16:26,221] Trial 107 finished with value: 1.8259481191635132 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.18594074485905415, 'layernorm': False, 'weight_init': 'he', 'lr': 0.00013017516625338815, 'optimizer': 'adamw', 'weight_decay': 4.564785491000741e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 105}. Best is trial 45 with value: -4.086929798126221.
# [I 2026-09-15 14:16:48,932] Trial 108 finished with value: -1.987410068511963 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.2018914861432685, 'layernorm': False, 'weight_init': 'he', 'lr': 0.019940759482861916, 'optimizer': 'adamw', 'weight_decay': 4.38466587637784e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 89}. Best is trial 45 with value: -4.086929798126221.
# [I 2026-09-15 14:17:12,753] Trial 109 finished with value: -3.745995044708252 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.17783609940365744, 'layernorm': False, 'weight_init': 'he', 'lr': 0.031484761206957715, 'optimizer': 'adamw', 'weight_decay': 3.9024086074368334e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 94}. Best is trial 45 with value: -4.086929798126221.
# [I 2026-09-15 14:17:35,291] Trial 110 finished with value: -3.1242172718048096 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.19534051766749522, 'layernorm': False, 'weight_init': 'he', 'lr': 0.02571328187227082, 'optimizer': 'adamw', 'weight_decay': 4.186224730865009e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 79}. Best is trial 45 with value: -4.086929798126221.
# [I 2026-09-15 14:17:57,956] Trial 111 finished with value: -4.041133880615234 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.16811103775912134, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04237960061912674, 'optimizer': 'adamw', 'weight_decay': 4.64614802697772e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 83}. Best is trial 45 with value: -4.086929798126221.
# [I 2026-09-15 14:18:20,962] Trial 112 finished with value: -4.023766040802002 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.24213549700834855, 'layernorm': False, 'weight_init': 'he', 'lr': 0.042748910405684154, 'optimizer': 'adamw', 'weight_decay': 4.716742881635092e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 83}. Best is trial 45 with value: -4.086929798126221.
# [I 2026-09-15 14:18:43,736] Trial 113 finished with value: -4.00517463684082 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.24157272654909406, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04206359939846981, 'optimizer': 'adamw', 'weight_decay': 4.718039478613507e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 74}. Best is trial 45 with value: -4.086929798126221.
# ...
# [I 2026-09-15 17:10:55,403] Trial 73 finished with value: -3.815718650817871 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.42862444325809135, 'layernorm': False, 'weight_init': 'he', 'lr': 0.03174976363902109, 'optimizer': 'adam', 'weight_decay': 8.529830299283982e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 142}. Best is trial 61 with value: -4.245108604431152.
# [I 2026-09-15 17:11:20,148] Trial 74 finished with value: -4.06299352645874 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.4686307705449917, 'layernorm': False, 'weight_init': 'he', 'lr': 0.04208892926399887, 'optimizer': 'adam', 'weight_decay': 9.121017962447548e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 113}. Best is trial 61 with value: -4.245108604431152.
# [I 2026-09-15 17:11:44,127] Trial 75 finished with value: -4.138442039489746 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.48130233549887, 'layernorm': False, 'weight_init': 'he', 'lr': 0.03811898858627333, 'optimizer': 'adam', 'weight_decay': 9.990525971042192e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 111}. Best is trial 61 with value: -4.245108604431152.
# [I 2026-09-15 17:12:06,694] Trial 76 finished with value: -3.2451438903808594 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.4802641393758921, 'layernorm': False, 'weight_init': 'he', 'lr': 0.023700777893981295, 'optimizer': 'adam', 'weight_decay': 9.949288682032681e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 109}. Best is trial 61 with value: -4.245108604431152.
# [I 2026-09-15 17:12:29,291] Trial 77 finished with value: -1.9370070695877075 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.4497344853484411, 'layernorm': False, 'weight_init': 'he', 'lr': 0.016177599768010333, 'optimizer': 'adam', 'weight_decay': 9.149126455416075e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 99}. Best is trial 61 with value: -4.245108604431152.
# [I 2026-09-15 17:12:51,241] Trial 78 finished with value: -4.062716007232666 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.47626910474977824, 'layernorm': False, 'weight_init': 'he', 'lr': 0.042589896457172725, 'optimizer': 'adamw', 'weight_decay': 9.448932739872422e-05, 'gradient_clip': 0.1, 'patience': 10, 'hidden_dim_0': 93}. Best is trial 61 with value: -4.245108604431152.
# [I 2026-09-15 17:13:13,668] Trial 79 finished with value: -3.7922914028167725 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0