# %% [markdown]
# # SPY Hybrid ERNN SI Self-lagged
#
# Original unrestricted model tuning with seven separately estimated nominal levels and the Bitcoin rank-based selection procedure.

# %%
# ============================================================
# SPY MODELLING DATA PREPARATION
# Common setup for all ERNN and QRNN specifications
# ============================================================

from pathlib import Path
import random
import numpy as np
import pandas as pd
import torch


# ------------------------------------------------------------
# 1. Reproducibility and device
# ------------------------------------------------------------

BASE_SEED = 2026

random.seed(BASE_SEED)
np.random.seed(BASE_SEED)
torch.manual_seed(BASE_SEED)

if torch.cuda.is_available():
    torch.cuda.manual_seed_all(BASE_SEED)

device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

print("Device:", device)


# ------------------------------------------------------------
# 2. Load the scaled SPY dataset
# ------------------------------------------------------------

DATA_PATH = Path.home() / "SPY_features_scaled.csv"

df = pd.read_csv(
    DATA_PATH,
    index_col="Date",
    parse_dates=True
)

df = (
    df
    .sort_index()
    .drop_duplicates()
    .dropna()
    .copy()
)


# ------------------------------------------------------------
# 3. Response and predictors
# ------------------------------------------------------------

target_col = "log_return"

feature_cols = [
    "Volatility",
    "RSI_14",
    "ATR_14",
    "QQQ_LogReturns",
    "VIX_LogChange",
    "Volume_LogChange",
]

required_cols = [target_col] + feature_cols

missing_cols = [
    column
    for column in required_cols
    if column not in df.columns
]

if missing_cols:
    raise ValueError(
        "Missing required columns: "
        + ", ".join(missing_cols)
    )


# ------------------------------------------------------------
# 4. Chronological 70%-15%-15% split
# ------------------------------------------------------------

train_size = int(len(df) * 0.70)
val_size = int(len(df) * 0.15)

train_df = df.iloc[:train_size].copy()
val_df = df.iloc[train_size:train_size + val_size].copy()
test_df = df.iloc[train_size + val_size:].copy()


# ------------------------------------------------------------
# 5. Convert samples to tensors
# ------------------------------------------------------------

def dataframe_to_tensors(sample):
    X = torch.tensor(
        sample[feature_cols].to_numpy(),
        dtype=torch.float32,
        device=device
    )
    y = torch.tensor(
        sample[target_col].to_numpy(),
        dtype=torch.float32,
        device=device
    )
    return X, y


X_train, y_train = dataframe_to_tensors(train_df)
X_val, y_val = dataframe_to_tensors(val_df)
X_test, y_test = dataframe_to_tensors(test_df)

# Compatibility aliases used by later QRNN cells.
X_test_q = X_test
y_test_q = y_test

levels = [
    0.025,
    0.050,
    0.250,
    0.500,
    0.750,
    0.950,
    0.975,
]

alpha_levels = levels
tau_levels = levels


# ------------------------------------------------------------
# 6. Checks and split summary
# ------------------------------------------------------------

assert len(X_train) == len(y_train)
assert len(X_val) == len(y_val)
assert len(X_test) == len(y_test)
assert X_train.shape[1] == len(feature_cols)
assert torch.isfinite(X_train).all()
assert torch.isfinite(X_val).all()
assert torch.isfinite(X_test).all()
assert torch.isfinite(y_train).all()
assert torch.isfinite(y_val).all()
assert torch.isfinite(y_test).all()

split_summary = pd.DataFrame({
    "Sample": ["Training", "Validation", "Test"],
    "Observations": [len(train_df), len(val_df), len(test_df)],
    "Start": [
        train_df.index.min().date(),
        val_df.index.min().date(),
        test_df.index.min().date(),
    ],
    "End": [
        train_df.index.max().date(),
        val_df.index.max().date(),
        test_df.index.max().date(),
    ],
})

display(split_summary)

print("Input features:", feature_cols)
print("Number of predictors:", len(feature_cols))
print("X_train shape:", tuple(X_train.shape))
print("X_val shape:  ", tuple(X_val.shape))
print("X_test shape: ", tuple(X_test.shape))
# Out:
# Device: cpu
#        Sample  Observations       Start         End
# 0    Training          2219  2014-01-23  2022-11-11
# 1  Validation           475  2022-11-14  2024-10-04
# 2        Test           476  2024-10-07  2026-08-31
# Input features: ['Volatility', 'RSI_14', 'ATR_14', 'QQQ_LogReturns', 'VIX_LogChange', 'Volume_LogChange']
# Number of predictors: 6
# X_train shape: (2219, 6)
# X_val shape:   (475, 6)
# X_test shape:  (476, 6)

# %% [markdown]
# ## Original tuning
#
# Run this cell after the SPY data-preparation cell.

# %%
# ============================================================
# ORIGINAL TUNING — SPY HYBRID ERNN SI SELF-LAGGED
# Seven separately estimated nominal levels
# 200 Optuna trials per level
# ============================================================

import copy
import json
import time

import optuna
import torch.nn as nn
import torch.nn.functional as F
from optuna.samplers import TPESampler


MODEL_NAME = "spy_ernn_si_self"
FORM = "SI"
LAG_TYPE = "self"
N_TRIALS = 200
MAX_EPOCHS = 200

TAU_LEVELS = [
    0.025,
    0.050,
    0.250,
    0.500,
    0.750,
    0.950,
    0.975,
]

OUTPUT_DIR = Path("spy_original_tuning_results") / MODEL_NAME
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print("Model:", MODEL_NAME)
print("Output directory:", OUTPUT_DIR.resolve())


# ------------------------------------------------------------
# 1. Reproducibility
# ------------------------------------------------------------

def set_model_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


# ------------------------------------------------------------
# 2. AGD negative log-likelihood
# ------------------------------------------------------------

def hybrid_ernn_loss(y, expectile_forecast, sigma, tau):
    """Mean asymmetric-Gaussian negative log-likelihood."""

    eps = torch.finfo(expectile_forecast.dtype).eps
    sigma = torch.clamp(sigma, min=eps)

    tau_tensor = torch.as_tensor(
        tau,
        dtype=expectile_forecast.dtype,
        device=expectile_forecast.device,
    )

    difference = y - expectile_forecast

    asymmetric_squared_error = (
        torch.abs(
            tau_tensor
            - (difference < 0).to(expectile_forecast.dtype)
        )
        * difference.pow(2)
    )

    pi_tensor = torch.as_tensor(
        torch.pi,
        dtype=expectile_forecast.dtype,
        device=expectile_forecast.device,
    )

    normalising_constant = (
        torch.log(
            torch.sqrt(pi_tensor / tau_tensor)
            + torch.sqrt(pi_tensor / (1.0 - tau_tensor))
        )
        - torch.log(
            torch.as_tensor(
                2.0,
                dtype=expectile_forecast.dtype,
                device=expectile_forecast.device,
            )
        )
    )

    observation_nll = (
        torch.log(sigma)
        + normalising_constant
        + asymmetric_squared_error / sigma.pow(2)
    )

    return observation_nll.mean()


# ------------------------------------------------------------
# 3. CARE-hybrid recursion
# ------------------------------------------------------------

def compute_hybrid_location(
    y,
    X,
    gamma1,
    gamma2,
    gamma3,
    fnn,
    psi,
):
    """SI-form self-lagged CARE-hybrid recursion."""

    fnn_output = fnn(X).squeeze(-1)
    zero_value = y.new_zeros(())

    care_forecasts = [zero_value]
    hybrid_forecasts = [zero_value]

    for time_index in range(1, len(y)):
        previous_return = y[time_index - 1]

        previous_state = care_forecasts[time_index - 1]
        absolute_return = torch.abs(previous_return)
        care_value = (
            gamma1 * previous_state
            + gamma2 * absolute_return
            + gamma3 * previous_state * absolute_return
        )

        hybrid_value = (
            psi * care_value
            + (1.0 - psi) * fnn_output[time_index]
        )

        care_forecasts.append(care_value)
        hybrid_forecasts.append(hybrid_value)

    return (
        torch.stack(hybrid_forecasts),
        torch.stack(care_forecasts),
    )


# ------------------------------------------------------------
# 4. Hybrid ERNN model
# ------------------------------------------------------------

class HybridERNN_SI_Self(nn.Module):
    def __init__(self, input_dim, config):
        super().__init__()

        self.eps = 1e-6

        self.gamma1_raw = nn.Parameter(
            torch.tensor(1.386)
        )

        self.gamma2_raw = nn.Parameter(
            torch.tensor(0.3)
        )

        self.gamma3_raw = nn.Parameter(
            torch.tensor(0.3)
        )
        self.psi_raw = nn.Parameter(
            torch.tensor(0.0)
        )

        self.sigma_raw = nn.Parameter(
            torch.tensor(0.5)
        )

        layers = []
        previous_dimension = input_dim

        for layer_index in range(config["n_hidden_layers"]):
            hidden_dimension = config[f"hidden_dim_{layer_index}"]

            layers.append(
                nn.Linear(previous_dimension, hidden_dimension)
            )

            if config["layernorm"]:
                layers.append(nn.LayerNorm(hidden_dimension))

            layers.append(
                self.get_activation(config["activation"])
            )

            if config["dropout"] > 0:
                layers.append(nn.Dropout(config["dropout"]))

            previous_dimension = hidden_dimension

        layers.append(nn.Linear(previous_dimension, 1))
        self.fnn = nn.Sequential(*layers)

        self.initialise_weights(config["weight_init"])

    @staticmethod
    def get_activation(name):
        return {
            "relu": nn.ReLU(),
            "elu": nn.ELU(),
            "gelu": nn.GELU(),
            "tanh": nn.Tanh(),
        }[name]

    def initialise_weights(self, method):
        for module in self.fnn.modules():
            if not isinstance(module, nn.Linear):
                continue

            if method == "glorot":
                nn.init.xavier_uniform_(module.weight)
            else:
                nn.init.kaiming_uniform_(module.weight)

            if module.bias is not None:
                nn.init.zeros_(module.bias)

    def forward(self, y, X):
        gamma1 = torch.sigmoid(self.gamma1_raw)
        gamma2 = F.softplus(self.gamma2_raw)

        gamma3 = F.softplus(
            self.gamma3_raw
        )
        psi = torch.sigmoid(self.psi_raw)
        sigma = F.softplus(self.sigma_raw) + self.eps

        hybrid_forecast, care_forecast = compute_hybrid_location(
            y=y,
            X=X,
            gamma1=gamma1,
            gamma2=gamma2,
            gamma3=gamma3,
            fnn=self.fnn,
            psi=psi,
        )

        return hybrid_forecast, sigma, care_forecast


# ------------------------------------------------------------
# 5. Original Bitcoin coverage-ratio ranking diagnostic
# ------------------------------------------------------------

def calculate_crp(y, forecast, tau):
    if tau <= 0.5:
        empirical_probability = (
            y <= forecast
        ).float().mean().item()
        target_probability = tau
    else:
        empirical_probability = (
            y > forecast
        ).float().mean().item()
        target_probability = 1.0 - tau

    crp = empirical_probability / target_probability
    crp_penalty = (crp - 1.0) ** 2

    return crp, crp_penalty, empirical_probability


# ------------------------------------------------------------
# 6. Optuna search space
# ------------------------------------------------------------

def suggest_ernn_config(trial):
    config = {
        "n_hidden_layers": trial.suggest_int(
            "n_hidden_layers", 1, 3
        ),
        "activation": trial.suggest_categorical(
            "activation", ["relu", "elu", "gelu", "tanh"]
        ),
        "dropout": trial.suggest_float(
            "dropout", 0.0, 0.5
        ),
        "layernorm": trial.suggest_categorical(
            "layernorm", [True, False]
        ),
        "weight_init": trial.suggest_categorical(
            "weight_init", ["glorot", "he"]
        ),
        "lr": trial.suggest_float(
            "lr", 1e-4, 5e-2, log=True
        ),
        "optimizer": trial.suggest_categorical(
            "optimizer", ["adam", "adamw"]
        ),
        "weight_decay": trial.suggest_float(
            "weight_decay", 0.0, 1e-4
        ),
        "gradient_clip": trial.suggest_categorical(
            "gradient_clip", [0.1, 1.0, 5.0]
        ),
        "patience": trial.suggest_categorical(
            "patience", [10, 20, 30]
        ),
    }

    for layer_index in range(config["n_hidden_layers"]):
        config[f"hidden_dim_{layer_index}"] = trial.suggest_int(
            f"hidden_dim_{layer_index}", 32, 256
        )

    return config


def make_optimizer(model, config):
    arguments = {
        "params": model.parameters(),
        "lr": config["lr"],
        "weight_decay": config["weight_decay"],
    }

    if config["optimizer"] == "adam":
        return torch.optim.Adam(**arguments)

    return torch.optim.AdamW(**arguments)


# ------------------------------------------------------------
# 7. Fit one trial configuration
# ------------------------------------------------------------

def train_ernn_configuration(config, tau, model_seed=BASE_SEED):
    set_model_seed(model_seed)

    model = HybridERNN_SI_Self(
        input_dim=X_train.shape[1],
        config=config,
    ).to(device)

    optimizer = make_optimizer(model, config)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode="min",
        patience=10,
        factor=0.5,
        min_lr=1e-6,
    )

    best_validation_nll = np.inf
    best_model_state = None
    patience_counter = 0
    epochs_completed = 0

    for epoch in range(MAX_EPOCHS):
        epochs_completed = epoch + 1

        model.train()
        optimizer.zero_grad()

        train_forecast, train_sigma, _ = model(y_train, X_train)

        train_loss = hybrid_ernn_loss(
            y=y_train,
            expectile_forecast=train_forecast,
            sigma=train_sigma,
            tau=tau,
        )

        if not torch.isfinite(train_loss):
            return None

        train_loss.backward()

        nn.utils.clip_grad_norm_(
            model.parameters(),
            config["gradient_clip"],
        )

        optimizer.step()

        model.eval()

        with torch.no_grad():
            validation_forecast, validation_sigma, _ = model(
                y_val,
                X_val,
            )

            validation_loss = hybrid_ernn_loss(
                y=y_val,
                expectile_forecast=validation_forecast,
                sigma=validation_sigma,
                tau=tau,
            )

        if not torch.isfinite(validation_loss):
            return None

        scheduler.step(validation_loss)
        current_validation_nll = validation_loss.item()

        if current_validation_nll < best_validation_nll:
            best_validation_nll = current_validation_nll
            best_model_state = copy.deepcopy(model.state_dict())
            patience_counter = 0
        else:
            patience_counter += 1

            if patience_counter >= config["patience"]:
                break

    if best_model_state is None:
        return None

    model.load_state_dict(best_model_state)
    model.eval()

    with torch.no_grad():
        validation_forecast, validation_sigma, _ = model(y_val, X_val)

        validation_nll = hybrid_ernn_loss(
            y=y_val,
            expectile_forecast=validation_forecast,
            sigma=validation_sigma,
            tau=tau,
        ).item()

        (
            validation_crp,
            validation_crp_penalty,
            validation_hit_rate,
        ) = calculate_crp(
            y=y_val,
            forecast=validation_forecast,
            tau=tau,
        )

    parameters = {
        "gamma1": torch.sigmoid(model.gamma1_raw).item(),
        "gamma2": F.softplus(model.gamma2_raw).item(),
        "gamma3": F.softplus(model.gamma3_raw).item(),
        "psi": torch.sigmoid(model.psi_raw).item(),
        "sigma": (F.softplus(model.sigma_raw) + model.eps).item(),
    }

    return {
        "model": model,
        "validation_nll": validation_nll,
        "validation_crp": validation_crp,
        "validation_crp_penalty": validation_crp_penalty,
        "validation_hit_rate": validation_hit_rate,
        "epochs_completed": epochs_completed,
        **parameters,
    }


# ------------------------------------------------------------
# 8. Optuna objective and rank-based selection
# ------------------------------------------------------------

def objective_ernn(trial, tau):
    config = suggest_ernn_config(trial)
    result = train_ernn_configuration(config, tau)

    if result is None:
        raise optuna.TrialPruned(
            "Non-finite loss or no valid checkpoint."
        )

    for name in [
        "validation_nll",
        "validation_crp",
        "validation_crp_penalty",
        "validation_hit_rate",
        "epochs_completed",
        "gamma1",
        "gamma2",
        "gamma3",
        "psi",
        "sigma",
    ]:
        trial.set_user_attr(name, result[name])

    return result["validation_nll"]


def rank_completed_trials(study):
    completed_trials = [
        trial
        for trial in study.trials
        if (
            trial.state == optuna.trial.TrialState.COMPLETE
            and trial.value is not None
            and np.isfinite(trial.value)
            and "validation_crp_penalty" in trial.user_attrs
        )
    ]

    if not completed_trials:
        raise RuntimeError("No valid completed Optuna trials.")

    nll_order = sorted(
        completed_trials,
        key=lambda trial: trial.user_attrs["validation_nll"],
    )

    crp_order = sorted(
        completed_trials,
        key=lambda trial: trial.user_attrs[
            "validation_crp_penalty"
        ],
    )

    nll_ranks = {
        trial.number: rank
        for rank, trial in enumerate(nll_order, start=1)
    }

    crp_ranks = {
        trial.number: rank
        for rank, trial in enumerate(crp_order, start=1)
    }

    ranking_records = []

    for trial in completed_trials:
        rank_nll = nll_ranks[trial.number]
        rank_crp = crp_ranks[trial.number]

        ranking_records.append({
            "trial": trial.number,
            **trial.user_attrs,
            "rank_nll": rank_nll,
            "rank_crp": rank_crp,
            "sum_rank": rank_nll + rank_crp,
            **trial.params,
        })

    ranking_table = pd.DataFrame(ranking_records)

    ranking_table = ranking_table.sort_values(
        [
            "sum_rank",
            "validation_nll",
            "validation_crp_penalty",
            "trial",
        ]
    ).reset_index(drop=True)

    selected_trial_number = int(ranking_table.iloc[0]["trial"])

    selected_trial = next(
        trial
        for trial in completed_trials
        if trial.number == selected_trial_number
    )

    return selected_trial, ranking_table


# ------------------------------------------------------------
# 9. Run 200 trials at each nominal level
# ------------------------------------------------------------

best_configs_spy_ernn_si_self = {}
best_models_spy_ernn_si_self = {}
summary_records = []

overall_start_time = time.time()

for level_index, tau in enumerate(TAU_LEVELS):
    level_start_time = time.time()
    sampler_seed = BASE_SEED + level_index

    print("\n" + "=" * 72)
    print(f"Tuning {MODEL_NAME} at tau={tau:.3f}")
    print(f"Trials={N_TRIALS} | sampler seed={sampler_seed}")
    print("=" * 72)

    study = optuna.create_study(
        direction="minimize",
        sampler=TPESampler(seed=sampler_seed),
        study_name=f"{MODEL_NAME}_tau_{tau:.3f}",
    )

    study.optimize(
        lambda trial, current_tau=tau: objective_ernn(
            trial,
            current_tau,
        ),
        n_trials=N_TRIALS,
        show_progress_bar=True,
        gc_after_trial=True,
    )

    selected_trial, ranking_table = rank_completed_trials(study)
    tau_label = f"{tau:.3f}"

    ranking_table.insert(0, "tau", tau)

    ranking_path = OUTPUT_DIR / (
        f"{MODEL_NAME}_ranking_tau_{tau_label}.csv"
    )

    ranking_table.to_csv(ranking_path, index=False)

    selected_config = selected_trial.params.copy()

    selected_result = train_ernn_configuration(
        selected_config,
        tau,
    )

    if selected_result is None:
        raise RuntimeError(
            f"Selected trial could not be reproduced for tau={tau}."
        )

    selected_model = selected_result["model"]

    checkpoint_path = OUTPUT_DIR / (
        f"{MODEL_NAME}_best_tau_{tau_label}.pt"
    )

    torch.save(
        {
            "model_name": MODEL_NAME,
            "asset": "SPY",
            "form": FORM,
            "lag_type": LAG_TYPE,
            "tau": tau,
            "selected_trial": selected_trial.number,
            "config": selected_config,
            "model_state_dict": {
                key: value.detach().cpu()
                for key, value in selected_model.state_dict().items()
            },
            "validation_nll": selected_result["validation_nll"],
            "validation_crp": selected_result["validation_crp"],
            "validation_crp_penalty": selected_result[
                "validation_crp_penalty"
            ],
            "validation_hit_rate": selected_result[
                "validation_hit_rate"
            ],
            "estimated_parameters": {
                name: selected_result[name]
                for name in [
                    "gamma1",
                    "gamma2",
                    "gamma3",
                    "psi",
                    "sigma",
                ]
            },
            "feature_cols": feature_cols,
            "number_of_trials": N_TRIALS,
            "base_seed": BASE_SEED,
            "sampler_seed": sampler_seed,
        },
        checkpoint_path,
    )

    selected_record = {
        **selected_config,
        "selected_trial": selected_trial.number,
        **{
            name: selected_result[name]
            for name in [
                "validation_nll",
                "validation_crp",
                "validation_crp_penalty",
                "validation_hit_rate",
                "gamma1",
                "gamma2",
                "gamma3",
                "psi",
                "sigma",
            ]
        },
    }

    best_configs_spy_ernn_si_self[tau] = selected_record
    best_models_spy_ernn_si_self[tau] = selected_model

    runtime_hours = (
        time.time() - level_start_time
    ) / 3600

    summary_records.append({
        "tau": tau,
        "selected_trial": selected_trial.number,
        "validation_nll": selected_result["validation_nll"],
        "validation_crp": selected_result["validation_crp"],
        "validation_crp_penalty": selected_result[
            "validation_crp_penalty"
        ],
        "validation_hit_rate": selected_result[
            "validation_hit_rate"
        ],
        "gamma1": selected_result["gamma1"],
        "gamma2": selected_result["gamma2"],
        "gamma3": selected_result["gamma3"],
        "psi": selected_result["psi"],
        "sigma": selected_result["sigma"],
        "valid_trials": len(ranking_table),
        "runtime_hours": runtime_hours,
    })

    print("\nTop 10 rank-based trials:")
    print(
        ranking_table[[
            "trial",
            "validation_nll",
            "validation_crp",
            "validation_crp_penalty",
            "rank_nll",
            "rank_crp",
            "sum_rank",
        ]].head(10).to_string(index=False)
    )

    print("\nSelected trial:", selected_trial.number)
    print(
        "Validation NLL:",
        f"{selected_result['validation_nll']:.8f}",
    )
    print(
        "Validation CRP:",
        f"{selected_result['validation_crp']:.8f}",
    )
    print("Ranking saved to:", ranking_path)
    print("Checkpoint saved to:", checkpoint_path)


summary_spy_ernn_si_self = pd.DataFrame(summary_records)

summary_path = OUTPUT_DIR / f"{MODEL_NAME}_tuning_summary.csv"
summary_spy_ernn_si_self.to_csv(summary_path, index=False)

config_path = OUTPUT_DIR / f"{MODEL_NAME}_selected_configs.json"

with open(config_path, "w") as configuration_file:
    json.dump(
        {
            f"{tau:.3f}": config
            for tau, config in best_configs_spy_ernn_si_self.items()
        },
        configuration_file,
        indent=2,
    )

print("\n" + "=" * 72)
print("SPY ORIGINAL ERNN TUNING COMPLETED:", MODEL_NAME)
print("=" * 72)
display(summary_spy_ernn_si_self)

print(
    "Total runtime (hours):",
    f"{(time.time() - overall_start_time) / 3600:.3f}",
)
print("Summary saved to:", summary_path)
print("Selected configurations saved to:", config_path)
# Out:
# [I 2026-09-15 13:36:08,697] A new study created in memory with name: spy_ernn_si_self_tau_0.025
# Model: spy_ernn_si_self
# Output directory: /Users/miaomiaochen/Desktop/PhD program/Project 1/spy_original_tuning_results/spy_ernn_si_self
#
# ========================================================================
# Tuning spy_ernn_si_self at tau=0.025
# Trials=200 | sampler seed=2026
# ========================================================================
#   0%|          | 0/200 [00:00<?, ?it/s]
# [I 2026-09-15 13:36:32,191] Trial 0 finished with value: 1.7633349895477295 and parameters: {'n_hidden_layers': 1, 'activation': 'elu', 'dropout': 0.49377524711883497, 'layernorm': False, 'weight_init': 'he', 'lr': 0.0006552020421842752, 'optimizer': 'adam', 'weight_decay': 8.940884610144999e-05, 'gradient_clip': 5.0, 'patience': 30, 'hidden_dim_0': 38}. Best is trial 0 with value: 1.7633349895477295.
# [I 2026-09-15 13:36:56,469] Trial 1 finished with value: 0.7268057465553284 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.07458356653667625, 'layernorm': False, 'weight_init': 'he', 'lr': 0.006969178688110181, 'optimizer': 'adam', 'weight_decay': 2.574006001095316e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 102}. Best is trial 1 with value: 0.7268057465553284.
# [I 2026-09-15 13:36:59,016] Trial 2 finished with value: 1.8468937873840332 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.37112272198735796, 'layernorm': True, 'weight_init': 'he', 'lr': 0.00010150090104324205, 'optimizer': 'adam', 'weight_decay': 6.518207314586205e-05, 'gradient_clip': 0.1, 'patience': 20, 'hidden_dim_0': 164}. Best is trial 1 with value: 0.7268057465553284.
# [I 2026-09-15 13:37:23,171] Trial 3 finished with value: 1.595321774482727 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.08410371275195383, 'layernorm': False, 'weight_init': 'he', 'lr': 0.0018347830260217095, 'optimizer': 'adamw', 'weight_decay': 1.0709415904194131e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 237}. Best is trial 1 with value: 0.7268057465553284.
# [I 2026-09-15 13:37:45,550] Trial 4 finished with value: 1.2283676862716675 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.04674566511461714, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.004179064253320389, 'optimizer': 'adam', 'weight_decay': 6.125656858808738e-05, 'gradient_clip': 5.0, 'patience': 20, 'hidden_dim_0': 104}. Best is trial 1 with value: 0.7268057465553284.
# [I 2026-09-15 13:37:48,252] Trial 5 finished with value: 1.8533332347869873 and parameters: {'n_hidden_layers': 2, 'activation': 'elu', 'dropout': 0.45911076747236795, 'layernorm': True, 'weight_init': 'he', 'lr': 0.0001416875352388753, 'optimizer': 'adam', 'weight_decay': 9.345394674549201e-05, 'gradient_clip': 1.0, 'patience': 20, 'hidden_dim_0': 223, 'hidden_dim_1': 87}. Best is trial 1 with value: 0.7268057465553284.
# [I 2026-09-15 13:37:50,972] Trial 6 finished with value: 1.85303795337677 and parameters: {'n_hidden_layers': 2, 'activation': 'elu', 'dropout': 0.38970064512862934, 'layernorm': True, 'weight_init': 'he', 'lr': 0.0006254792571683692, 'optimizer': 'adamw', 'weight_decay': 6.801313798751197e-05, 'gradient_clip': 0.1, 'patience': 10, 'hidden_dim_0': 218, 'hidden_dim_1': 178}. Best is trial 1 with value: 0.7268057465553284.
# [I 2026-09-15 13:37:56,152] Trial 7 finished with value: 1.8454351425170898 and parameters: {'n_hidden_layers': 2, 'activation': 'gelu', 'dropout': 0.36032432475263065, 'layernorm': True, 'weight_init': 'he', 'lr': 0.00020173841324002415, 'optimizer': 'adam', 'weight_decay': 4.1767279869402754e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0': 154, 'hidden_dim_1': 109}. Best is trial 1 with value: 0.7268057465553284.
# [I 2026-09-15 13:37:58,117] Trial 8 finished with value: 1.8453543186187744 and parameters: {'n_hidden_layers': 3, 'activation': 'relu', 'dropout': 0.4362763457742629, 'layernorm': False, 'weight_init': 'he', 'lr': 0.0005717356849949265, 'optimizer': 'adamw', 'weight_decay': 9.916771691263823e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 79, 'hidden_dim_1': 56, 'hidden_dim_2': 37}. Best is trial 1 with value: 0.7268057465553284.
# [I 2026-09-15 13:38:23,826] Trial 9 finished with value: 1.8296988010406494 and parameters: {'n_hidden_layers': 3, 'activation': 'relu', 'dropout': 0.013151451801451775, 'layernorm': False, 'weight_init': 'he', 'lr': 0.00012716878126572782, 'optimizer': 'adam', 'weight_decay': 1.9095096534588543e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 51, 'hidden_dim_1': 132, 'hidden_dim_2': 126}. Best is trial 1 with value: 0.7268057465553284.
# [I 2026-09-15 13:38:46,910] Trial 10 finished with value: -3.7205536365509033 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.15097474024909283, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.037908135375982255, 'optimizer': 'adamw', 'weight_decay': 3.1379335590221484e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 119}. Best is trial 10 with value: -3.7205536365509033.
# [I 2026-09-15 13:39:10,779] Trial 11 finished with value: -3.726242780685425 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.16366513375091546, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.03402526330326022, 'optimizer': 'adamw', 'weight_decay': 3.117485972962536e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 121}. Best is trial 11 with value: -3.726242780685425.
# [I 2026-09-15 13:39:34,306] Trial 12 finished with value: -3.9296016693115234 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.19279633488923958, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.046620580362009216, 'optimizer': 'adamw', 'weight_decay': 3.4990129609403785e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 128}. Best is trial 12 with value: -3.9296016693115234.
# [I 2026-09-15 13:40:00,114] Trial 13 finished with value: -1.7518672943115234 and parameters: {'n_hidden_layers': 2, 'activation': 'tanh', 'dropout': 0.23786332849750252, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.0422935363306104, 'optimizer': 'adamw', 'weight_decay': 4.3617650808427846e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 192, 'hidden_dim_1': 239}. Best is trial 12 with value: -3.9296016693115234.
# [I 2026-09-15 13:40:23,290] Trial 14 finished with value: -1.1916974782943726 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.22057191497197615, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.016347204119543955, 'optimizer': 'adamw', 'weight_decay': 7.599168284062825e-07, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 134}. Best is trial 12 with value: -3.9296016693115234.
# [I 2026-09-15 13:40:49,638] Trial 15 finished with value: -1.1082245111465454 and parameters: {'n_hidden_layers': 2, 'activation': 'tanh', 'dropout': 0.16517512170768736, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.016298529041495768, 'optimizer': 'adamw', 'weight_decay': 3.5934740730597646e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 176, 'hidden_dim_1': 242}. Best is trial 12 with value: -3.9296016693115234.
# [I 2026-09-15 13:41:12,437] Trial 16 finished with value: -1.4040732383728027 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.3070978356512841, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.01725021139952443, 'optimizer': 'adamw', 'weight_decay': 4.984887925511083e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 75}. Best is trial 12 with value: -3.9296016693115234.
# [I 2026-09-15 13:41:40,506] Trial 17 finished with value: 0.5199910402297974 and parameters: {'n_hidden_layers': 3, 'activation': 'tanh', 'dropout': 0.14427051645389266, 'layernorm': False, 'weight_init': 'glorot', 'lr': 0.00800604547474574, 'optimizer': 'adamw', 'weight_decay': 1.3722887436408784e-05, 'gradient_clip': 1.0, 'patience': 30, 'hidden_dim_0': 134, 'hidden_dim_1': 180, 'hidden_dim_2': 249}. Best is trial 12 with value: -3.9296016693115234.
# [I 2026-09-15 13:42:06,099] Trial 18 finished with value: -3.632301092147827 and parameters: {'n_hidden_layers': 2, 'activation': 'gelu', 'dropout': 0.290549643868981, 'layernorm': True, 'weight_init': 'glorot', 'lr': 0.0464822393550214, 'optimizer': 'adamw', 'weight_decay': 5.638805838779985e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0':
and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.31245357778571314, 'layernorm': False, 'weight_init': 'he', 'lr': 0.03637233748812676, 'optimizer': 'adamw', 'weight_decay': 6.664563088219742e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 47}. Best is trial 89 with value: -4.020991325378418.
# [I 2026-09-15 14:12:31,220] Trial 97 finished with value: -3.9541895389556885 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.31276213390668633, 'layernorm': False, 'weight_init': 'he', 'lr': 0.03706065732168872, 'optimizer': 'adamw', 'weight_decay': 6.592720983783562e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 59}. Best is trial 89 with value: -4.020991325378418.
# [I 2026-09-15 14:12:54,374] Trial 98 finished with value: -3.836416244506836 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.32590353909378067, 'layernorm': False, 'weight_init': 'he', 'lr': 0.032237292089957494, 'optimizer': 'adamw', 'weight_decay': 6.754577083761025e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 59}. Best is trial 89 with value: -4.020991325378418.
# [I 2026-09-15 14:13:17,433] Trial 99 finished with value: 1.634854793548584 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.34488707931161583, 'layernorm': False, 'weight_init': 'he', 'lr': 0.001551127441097618, 'optimizer': 'adam', 'weight_decay': 5.379279588677098e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 46}. Best is trial 89 with value: -4.020991325378418.
# [I 2026-09-15 14:13:41,532] Trial 100 finished with value: -1.7881752252578735 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.3110318997019834, 'layernorm': True, 'weight_init': 'he', 'lr': 0.019086417856057608, 'optimizer': 'adamw', 'weight_decay': 5.929633230446613e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 73}. Best is trial 89 with value: -4.020991325378418.
# [I 2026-09-15 14:14:05,215] Trial 101 finished with value: -3.9860172271728516 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.3112691877808161, 'layernorm': False, 'weight_init': 'he', 'lr': 0.037533505621569735, 'optimizer': 'adamw', 'weight_decay': 6.538992201351027e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 50}. Best is trial 89 with value: -4.020991325378418.
# [I 2026-09-15 14:14:28,558] Trial 102 finished with value: 1.8360117673873901 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.29334993854386043, 'layernorm': False, 'weight_init': 'he', 'lr': 0.00010224127000158946, 'optimizer': 'adamw', 'weight_decay': 6.288932873193191e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 49}. Best is trial 89 with value: -4.020991325378418.
# [I 2026-09-15 14:14:51,227] Trial 103 finished with value: -4.000568866729736 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.28022330652700705, 'layernorm': False, 'weight_init': 'he', 'lr': 0.03549619422506363, 'optimizer': 'adamw', 'weight_decay': 6.658674769773524e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 39}. Best is trial 89 with value: -4.020991325378418.
# [I 2026-09-15 14:15:14,314] Trial 104 finished with value: 1.022152066230774 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.27336219118954186, 'layernorm': False, 'weight_init': 'he', 'lr': 0.005268318784725249, 'optimizer': 'adamw', 'weight_decay': 7.350195432794241e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 51}. Best is trial 89 with value: -4.020991325378418.
# [I 2026-09-15 14:15:36,617] Trial 105 finished with value: -3.4585609436035156 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.24962154280441087, 'layernorm': False, 'weight_init': 'he', 'lr': 0.027694688098362015, 'optimizer': 'adamw', 'weight_decay': 5.676712669653503e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 38}. Best is trial 89 with value: -4.020991325378418.
# [I 2026-09-15 14:15:59,208] Trial 106 finished with value: -4.010874271392822 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.2634841915367291, 'layernorm': False, 'weight_init': 'he', 'lr': 0.03663649113003412, 'optimizer': 'adamw', 'weight_decay': 6.487272401392014e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 43}. Best is trial 89 with value: -4.020991325378418.
# [I 2026-09-15 14:16:24,775] Trial 107 finished with value: -2.8470447063446045 and parameters: {'n_hidden_layers': 3, 'activation': 'gelu', 'dropout': 0.2847089254570584, 'layernorm': False, 'weight_init': 'he', 'lr': 0.02474381349708712, 'optimizer': 'adamw', 'weight_decay': 6.292067332525207e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 44, 'hidden_dim_1': 32, 'hidden_dim_2': 193}. Best is trial 89 with value: -4.020991325378418.
# [I 2026-09-15 14:16:47,335] Trial 108 finished with value: -4.022215366363525 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.2623388682525622, 'layernorm': False, 'weight_init': 'he', 'lr': 0.0371919442653809, 'optimizer': 'adamw', 'weight_decay': 6.784432819889343e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 39}. Best is trial 108 with value: -4.022215366363525.
# [I 2026-09-15 14:17:10,814] Trial 109 finished with value: -0.056828733533620834 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.2606618440550276, 'layernorm': False, 'weight_init': 'he', 'lr': 0.010885903445613054, 'optimizer': 'adamw', 'weight_decay': 5.775222808681219e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 37}. Best is trial 108 with value: -4.022215366363525.
# [I 2026-09-15 14:17:34,565] Trial 110 finished with value: -3.6233668327331543 and parameters: {'n_hidden_layers': 2, 'activation': 'gelu', 'dropout': 0.23149538051734164, 'layernorm': False, 'weight_init': 'he', 'lr': 0.030407041968746086, 'optimizer': 'adamw', 'weight_decay': 6.930587747989356e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 79, 'hidden_dim_1': 62}. Best is trial 108 with value: -4.022215366363525.
# [I 2026-09-15 14:17:57,188] Trial 111 finished with value: -3.9522693157196045 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.24413910115284837, 'layernorm': False, 'weight_init': 'he', 'lr': 0.037484991715544716, 'optimizer': 'adamw', 'weight_decay': 6.61096030451937e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 42}. Best is trial 108 with value: -4.022215366363525.
# [I 2026-09-15 14:18:20,243] Trial 112 finished with value: -3.869328260421753 and parameters: {'n_hidden_layers': 1, 'activation': 'gelu', 'dropout': 0.3269008562085698, 'layernorm': False, 'weight_init': 'he', 'lr': 0.0327466023923305, 'optimizer': 'adamw', 'weight_decay': 6.113938307875527e-05, 'gradient_clip': 5.0, 'patience': 10, 'hidden_dim_0': 47}. Best is trial 108 with value: -4.022215366363525.
# ...
# [I 2026-09-15 17:10:42,892] Trial 60 finished with value: -3.710117816925049 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.08790747758074594, 'layernorm': True, 'weight_init': 'he', 'lr': 0.04795198702791511, 'optimizer': 'adamw', 'weight_decay': 8.307403556246656e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 62}. Best is trial 44 with value: -3.8759665489196777.
# [I 2026-09-15 17:11:04,095] Trial 61 finished with value: -3.6393656730651855 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.11628182540318055, 'layernorm': True, 'weight_init': 'he', 'lr': 0.038243647975944185, 'optimizer': 'adamw', 'weight_decay': 8.225423237247798e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 57}. Best is trial 44 with value: -3.8759665489196777.
# [I 2026-09-15 17:11:26,787] Trial 62 finished with value: -3.6964762210845947 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.04703328700131456, 'layernorm': True, 'weight_init': 'he', 'lr': 0.04032315938492148, 'optimizer': 'adamw', 'weight_decay': 8.691761760793326e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 60}. Best is trial 44 with value: -3.8759665489196777.
# [I 2026-09-15 17:11:44,680] Trial 63 finished with value: -3.6510186195373535 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.0823476421224939, 'layernorm': True, 'weight_init': 'he', 'lr': 0.04822901276492078, 'optimizer': 'adamw', 'weight_decay': 8.66955636064465e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 73}. Best is trial 44 with value: -3.8759665489196777.
# [I 2026-09-15 17:12:07,649] Trial 64 finished with value: -3.9077625274658203 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.011229652299315704, 'layernorm': True, 'weight_init': 'he', 'lr': 0.039098190022505315, 'optimizer': 'adamw', 'weight_decay': 7.657197674123357e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 87}. Best is trial 64 with value: -3.9077625274658203.
# [I 2026-09-15 17:12:30,733] Trial 65 finished with value: -2.6013450622558594 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.029256257955124692, 'layernorm': True, 'weight_init': 'he', 'lr': 0.01912725362674263, 'optimizer': 'adamw', 'weight_decay': 7.649558288071409e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 88}. Best is trial 64 with value: -3.9077625274658203.
# [I 2026-09-15 17:12:53,726] Trial 66 finished with value: -3.921574831008911 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.009347268273566245, 'layernorm': True, 'weight_init': 'he', 'lr': 0.038987148540012194, 'optimizer': 'adamw', 'weight_decay': 9.453260362766562e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0':
and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.027131297534544352, 'layernorm': True, 'weight_init': 'he', 'lr': 0.04949891122792671, 'optimizer': 'adamw', 'weight_decay': 7.39505902959763e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 52}. Best is trial 77 with value: -4.169936656951904.
# [I 2026-09-15 17:17:33,997] Trial 79 finished with value: -3.209322690963745 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.10582218102929272, 'layernorm': True, 'weight_init': 'he', 'lr': 0.027780676298609815, 'optimizer': 'adamw', 'weight_decay': 8.427579190118567e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 40}. Best is trial 77 with value: -4.169936656951904.
# [I 2026-09-15 17:17:56,700] Trial 80 finished with value: -3.675039291381836 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.0012454351135305418, 'layernorm': True, 'weight_init': 'he', 'lr': 0.03115408283044376, 'optimizer': 'adamw', 'weight_decay': 8.011422330048453e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 66}. Best is trial 77 with value: -4.169936656951904.
# [I 2026-09-15 17:18:16,927] Trial 81 finished with value: -3.7446229457855225 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.04877896110297551, 'layernorm': True, 'weight_init': 'he', 'lr': 0.04075167211090613, 'optimizer': 'adamw', 'weight_decay': 8.858627123262399e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 42}. Best is trial 77 with value: -4.169936656951904.
# [I 2026-09-15 17:18:40,609] Trial 82 finished with value: -3.726337432861328 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.07042911808164051, 'layernorm': True, 'weight_init': 'he', 'lr': 0.0349808294330105, 'optimizer': 'adamw', 'weight_decay': 8.500645784439122e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 81}. Best is trial 77 with value: -4.169936656951904.
# [I 2026-09-15 17:19:01,349] Trial 83 finished with value: -3.8506267070770264 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.031957748501366984, 'layernorm': True, 'weight_init': 'he', 'lr': 0.043792214102241454, 'optimizer': 'adamw', 'weight_decay': 9.530319645052553e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 55}. Best is trial 77 with value: -4.169936656951904.
# [I 2026-09-15 17:19:24,332] Trial 84 finished with value: -3.354182481765747 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.03824738145076631, 'layernorm': True, 'weight_init': 'he', 'lr': 0.02598858426253149, 'optimizer': 'adamw', 'weight_decay': 9.572840393107597e-05, 'gradient_clip': 1.0, 'patience': 10, 'hidden_dim_0': 55}. Best is trial 77 with value: -4.169936656951904.
# [I 2026-09-15 17:19:47,076] Trial 85 finished with value: -4.048195838928223 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.0015306703191859498, 'layernorm': True, 'weight_init': 'he', 'lr': 0.04990305933240782, 'optimizer': 'adamw', 'weight_decay': 7.496103200692808e-05, 'gradient_clip': 0.1, 'patience': 10, 'hidden_dim_0': 32}. Best is trial 77 with value: -4.169936656951904.
# [I 2026-09-15 17:20:09,757] Trial 86 finished with value: -3.858036518096924 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.003713911167089856, 'layernorm': True, 'weight_init': 'he', 'lr': 0.0433153073272461, 'optimizer': 'adamw', 'weight_decay': 6.515171764302683e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0': 35}. Best is trial 77 with value: -4.169936656951904.
# [I 2026-09-15 17:20:32,787] Trial 87 finished with value: -3.9459235668182373 and parameters: {'n_hidden_layers': 1, 'activation': 'relu', 'dropout': 0.0028712880389583193, 'layernorm': True, 'weight_init': 'he', 'lr': 0.049973835058563905, 'optimizer': 'adamw', 'weight_decay': 6.591190287176682e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0': 34}. Best is trial 77 with value: -4.169936656951904.
# [I 2026-09-15 17:20:55,964] Trial 88 finished with value: -3.9864468574523926 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.0019891138992330247, 'layernorm': True, 'weight_init': 'he', 'lr': 0.049615829386503045, 'optimizer': 'adamw', 'weight_decay': 6.466528894581266e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0': 34}. Best is trial 77 with value: -4.169936656951904.
# [I 2026-09-15 17:21:19,218] Trial 89 finished with value: -3.982384443283081 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.0010581746493241477, 'layernorm': True, 'weight_init': 'he', 'lr': 0.049181040681907935, 'optimizer': 'adamw', 'weight_decay': 6.483404601503175e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0': 34}. Best is trial 77 with value: -4.169936656951904.
# [I 2026-09-15 17:41:19,452] Trial 114 finished with value: -3.699259042739868 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.01648351515960474, 'layernorm': True, 'weight_init': 'he', 'lr': 0.03501596062501302, 'optimizer': 'adam', 'weight_decay': 6.686307543588258e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0': 38}. Best is trial 101 with value: -4.17063570022583.
# [I 2026-09-15 18:03:26,680] Trial 115 finished with value: -3.922408103942871 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.032939558754547425, 'layernorm': True, 'weight_init': 'he', 'lr': 0.042478937342356915, 'optimizer': 'adam', 'weight_decay': 5.7832089407731115e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0': 32}. Best is trial 101 with value: -4.17063570022583.
# [I 2026-09-15 18:03:52,494] Trial 116 finished with value: -3.627883195877075 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.04385625115006484, 'layernorm': True, 'weight_init': 'glorot', 'lr': 0.033068369154978294, 'optimizer': 'adam', 'weight_decay': 7.007075858218097e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0': 49}. Best is trial 101 with value: -4.17063570022583.
# [I 2026-09-15 18:08:22,429] Trial 117 finished with value: 0.31676360964775085 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.07349720098844736, 'layernorm': True, 'weight_init': 'he', 'lr': 0.0046971026297719905, 'optimizer': 'adam', 'weight_decay': 7.54085494256744e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0': 43}. Best is trial 101 with value: -4.17063570022583.
# [I 2026-09-15 18:24:50,217] Trial 118 finished with value: -3.894475221633911 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.0617723565773103, 'layernorm': True, 'weight_init': 'he', 'lr': 0.042015921549101116, 'optimizer': 'adam', 'weight_decay': 5.534231742158271e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0': 53}. Best is trial 101 with value: -4.17063570022583.
# [I 2026-09-15 18:55:15,231] Trial 119 finished with value: -3.2378456592559814 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.013106369205465556, 'layernorm': True, 'weight_init': 'he', 'lr': 0.026624215192770962, 'optimizer': 'adam', 'weight_decay': 6.859914986420981e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0': 38}. Best is trial 101 with value: -4.17063570022583.
# [I 2026-09-15 19:10:40,048] Trial 120 finished with value: -3.7795770168304443 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.025685866862135497, 'layernorm': True, 'weight_init': 'he', 'lr': 0.03693716930437364, 'optimizer': 'adam', 'weight_decay': 6.33984459919889e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0': 47}. Best is trial 101 with value: -4.17063570022583.
# [I 2026-09-15 19:31:46,974] Trial 121 finished with value: -3.9467010498046875 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.05105558396944844, 'layernorm': True, 'weight_init': 'he', 'lr': 0.04945740846392876, 'optimizer': 'adam', 'weight_decay': 6.150525955035347e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0': 43}. Best is trial 101 with value: -4.17063570022583.
# [I 2026-09-15 19:47:10,187] Trial 122 finished with value: -3.9249322414398193 and parameters: {'n_hidden_layers': 1, 'activation': 'tanh', 'dropout': 0.04651069491013991, 'layernorm': True, 'weight_init': 'he', 'lr': 0.04393211759342381, 'optimizer': 'adam', 'weight_decay': 7.13704492998879e-05, 'gradient_clip': 0.1, 'patience': 30, 'hidden_dim_0': 38}. Best is trial 101 with value: -4.17063570022583.
